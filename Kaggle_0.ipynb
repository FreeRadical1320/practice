# %%
# Standard python libraries
import os
import time

# Essential DS libraries
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
import torch

# # LightAutoML presets, task and report generation
# from lightautoml.automl.presets.tabular_presets import TabularAutoML
# from lightautoml.tasks import Task

# %%
N_THREADS = 4
N_FOLDS = 5
RANDOM_STATE = 42
TEST_SIZE = 0.2
TIMEOUT = 1500 # equal to 25 minutes
TARGET_NAME = 'final_price'

# %%
np.random.seed(RANDOM_STATE)
torch.set_num_threads(N_THREADS)

# %%
INPUT_DIR = './Kaggle_0/'

# %%
train_data = pd.read_csv(INPUT_DIR + 'train_data.csv')
print(train_data.shape)
train_data.head(3)
# Out:
# (35000, 15)
#    row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 0       0               TOYOTA        Aqua s            Sedan
# 1       1        MERCEDES-BENZ         C 220            Sedan
# 2       2              HYUNDAI      Veloster        Hatchback
#
#    current_mileage  vehicle_year vehicle_gearbox_type doors_cnt  \
# 0           133000          2014            Automatic       4/5
# 1            24500          2010               Manual       4/5
# 2            31000          2016            Tiptronic       2/3
#
#                   wheels vehicle_color vehicle_interior_color  \
# 0    Right-hand drive          Silver                  Black
# 1           Left wheel         Silver                  Black
# 2           Left wheel         Silver                  Black
#
#                car_vin  car_leather_interior deal_type  final_price
# 0                  NaN                     0  For Sale       3650.0
# 1                  NaN                     0  For Sale       6800.0
# 2   KMHTC6AE3GU293912                      1  For Sale       6300.0

# %%
test_data = pd.read_csv(INPUT_DIR + 'test_data.csv')
print(test_data.shape)
test_data.head(3)
# Out:
# (10697, 14)
#    row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 0   35000               TOYOTA         Prius        Hatchback
# 1   35001              HYUNDAI       Elantra            Sedan
# 2   35002                LEXUS        NX 300             Jeep
#
#    current_mileage  vehicle_year vehicle_gearbox_type doors_cnt  \
# 0           323733          2012            Automatic       4/5
# 1           112000          2013            Tiptronic       4/5
# 2            16920          2018            Automatic       NaN
#
#            wheels vehicle_color vehicle_interior_color              car_vin  \
# 0    Left wheel           Grey                  Black    JTDKN3DU6C5439638
# 1    Left wheel           Grey                  Black            SURATSHIA
# 2    Left wheel          Brown                     NaN   JTJYARBZ5J2104521
#
#    car_leather_interior deal_type
# 0                     1  For Sale
# 1                     1  For Sale
# 2                     1  For Sale

# %%
submission = pd.read_csv(INPUT_DIR + 'sample_submission.csv')
print(submission.shape)
submission.head(3)
# Out:
# (10697, 2)
#    row_ID  final_price
# 0   35000            0
# 1   35001            0
# 2   35002            0

# %%
train_data[train_data['vehicle_model'] == 'C 220']

# %%
train_data.head()
# Out:
#    row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 0       0               TOYOTA        Aqua s            Sedan
# 1       1        MERCEDES-BENZ         C 220            Sedan
# 2       2              HYUNDAI      Veloster        Hatchback
# 3       3              HYUNDAI      Santa FE             Jeep
# 4       4               TOYOTA           CHR             Jeep
#
#    current_mileage  vehicle_year vehicle_gearbox_type doors_cnt  \
# 0           133000          2014            Automatic       4/5
# 1            24500          2010               Manual       4/5
# 2            31000          2016            Tiptronic       2/3
# 3           115459          2015            Automatic       4/5
# 4            18950          2019            Automatic       4/5
#
#                   wheels vehicle_color vehicle_interior_color car_vin  \
# 0    Right-hand drive          Silver                  Black      JTN
# 1           Left wheel         Silver                  Black    4JG20
# 2           Left wheel         Silver                  Black    MHTC6
# 3           Left wheel           Blue                  Black    KMHS2
# 4           Left wheel          Black                     NaN   TNKHM
#
#    car_leather_interior deal_type  final_price  car_wearout_ratio
# 0                     0  For Sale       3650.0           0.939850
# 1                     0  For Sale       6800.0           3.401361
# 2                     1  For Sale       6300.0           5.376344
# 3                     1  For Sale      14488.0           1.237298
# 4                     1  For Sale       5000.0          17.590150

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35000 entries, 0 to 34999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   row_ID                  35000 non-null  int64
#  1   vehicle_manufacturer    34999 non-null  object
#  2   vehicle_model           34993 non-null  object
#  3   vehicle_category        34999 non-null  object
#  4   current_mileage         35000 non-null  int64
#  5   vehicle_year            35000 non-null  int64
#  6   vehicle_gearbox_type    34999 non-null  object
#  7   doors_cnt               34255 non-null  object
#  8   wheels                  34999 non-null  object
#  9   vehicle_color           34599 non-null  object
#  10  vehicle_interior_color  28282 non-null  object
#  11  car_vin                 11488 non-null  object
#  12  car_leather_interior    35000 non-null  int64
#  13  deal_type               35000 non-null  object
#  14  final_price             35000 non-null  float64
# dtypes: float64(1), int64(4), object(10)
# memory usage: 4.0+ MB

# %%
# def append_wmi(wmis, vendor, car_vin):
#     """ This function appends new element in dictionary
#         if not exist

#     Args:
#         wmis (dictionary of the lists of the codes) like {'manufacturer": ['JTG', '1T4', ... 'JTD']} 
#         vendor (text string): name of the vehicle manufacturer
#         car_vin (text string): serial of the numbers and symbols (max 17)
#     """
#     if car_vin in ['nan', 'NaN']:
#         return
#     wmi = car_vin[:3]
  
#     if vendor not in wmis.keys():
#         wmis.update({vendor: list()})
#         wmis[vendor].append(wmi)
    
#     elif wmi not in wmis[vendor]:
#         wmis[vendor].append(wmi)
      
#     return


# def append_vds(vdss, model, car_vin):
#     """ This function appends new element in dictionary
#         if not exist

#     Args:
#         vdcs (dictionary of the lists of the codes) like {'model": ['XC', 'SD', ... 'SC']}
#         model (text string): name of the vehicle model
#         car_vin (text string): serial of the numbers and symbols (max 17)
#     """
#     if car_vin in ['nan', 'NaN'] or not len(model):
#         return
#     vds = car_vin[3:5]
  
#     if model not in vdss.keys():
#         vdss.update({model: list()})
#         vdss[model].append(vds)
     
#     elif vds not in vdss[model]:
#         vdss[model].append(vds)
       
#     return


# def get_vin_parts(df):
#     """ This function collect existing vin-codes into dictionary
#         for future implementations

#     Args:
#         df (pandas.DataFrame): The source data that we use for collecting
#     Returns:
#         wmis_dict (dictionary of the lists of the codes) like {'manufacturer": ['JTG', '1T4', ... 'JTD']} 
#         vdcs_dict (dictionary of the lists of the codes) like {'model": ['XC', 'SD', ... 'SC']}
#     """
#     # Create empty dictionaries
#     wmi_dict = dict()
#     vds_dict = dict()
    
#     # Go along the rows by indexes
#     for row in df.index:
#         car_vin = str(df['car_vin'].iloc[row])

#         if len(car_vin) > 3:
            
#             vendor = str(df['vehicle_manufacturer'].iloc[row])
#             # Get World Manufacturers Identification (wmi)
#             append_wmi(wmi_dict, vendor, car_vin)
            
#             model = str(df['vehicle_model'].iloc[row])
#             # Get Vehicle Description Section (vds)
#             append_vds(vds_dict, model, car_vin)
            
#     return wmi_dict, vds_dict


# def set_vin(wmis, vdss, df):
#     """ This function set vin-codes for empty cells
#         using vendor and model information

#     Args:
#         wmis (dictionary of the lists of the codes) like {'manufacturer": ['JTG', '1T4', ... 'JTD']} 
#         vdcs (dictionary of the lists of the codes) like {'model": ['XC', 'SD', ... 'SC']}
#         df (pandas.DataFrame): The source dataframe

#     Returns:
#         pandas.DataFrame: output dataframe
#     """
#     for row in df.index:
#         car_vin = str(df['car_vin'].iloc[row])
        
#         if car_vin in ['nan', 'NaN']:
#             vendor = str(df['vehicle_manufacturer'].iloc[row])
#             model = str(df['vehicle_model'].iloc[row])
            
#             if vendor in wmis.keys():
#                 car_vin = wmis[vendor][0]
#             else:
#                 car_vin = 'nan'
#             if model in vdss.keys():
#                 car_vin += vdss[model][0]
#         else:
#             car_vin = car_vin[1:6]
#         df['car_vin'].iloc[row] = car_vin
                
#     return df

# %%
def append_wmi_vds(vins, vendor, model, body_type,car_vin):
    """ This function appends new element in dictionary
        if not exist

    Args:
        wmis (dictionary of the lists of the codes) like {'manufacturer": ['JTG', '1T4', ... 'JTD']} 
        vendor (text string): name of the vehicle manufacturer
        car_vin (text string): serial of the numbers and symbols (max 17)
    """
    if car_vin in ['nan', 'NaN']:
        return
    vin_part = car_vin[:7]
    vehicle = vendor + ' ' + model + ' ' + body_type
  
    if vehicle not in vins.keys():
        vins.update({vehicle: list()})
        vins[vehicle].append(vin_part)
    
    elif vin_part not in vins[vehicle]:
        vins[vehicle].append(vin_part)
      
    return



def get_vin_parts(df):
    """ This function collect existing vin-codes into dictionary
        for future implementations

    Args:
        df (pandas.DataFrame): The source data that we use for collecting
    Returns:
        wmis_dict (dictionary of the lists of the codes) like {'manufacturer": ['JTG', '1T4', ... 'JTD']} 
        vdcs_dict (dictionary of the lists of the codes) like {'model": ['XC', 'SD', ... 'SC']}
    """
    # Create empty dictionary
    vin_dict = dict()
    
    # Go along the rows by indexes
    for row in df.index:
        car_vin = str(df['car_vin'].iloc[row])

        if len(car_vin) > 3:
            vendor = str(df['vehicle_manufacturer'].iloc[row])
            model = str(df['vehicle_model'].iloc[row])
            body_type = str(df['vehicle_category'].iloc[row])
            
            # Get World Manufacturers Identification (wmi) + Vehicle Description Section (vds)
            append_wmi_vds(vin_dict, vendor, model, body_type, car_vin)
            
    return vin_dict


def set_vin_parts(vins, df):
    """ This function set vin-codes for empty cells
        using vendor and model information

    Args:
        wmis (dictionary of the lists of the codes) like {'manufacturer": ['JTG', '1T4', ... 'JTD']} 
        vdcs (dictionary of the lists of the codes) like {'model": ['XC', 'SD', ... 'SC']}
        df (pandas.DataFrame): The source dataframe

    Returns:
        pandas.DataFrame: output dataframe
    """
    for row in df.index:
        car_vin = str(df['car_vin'].iloc[row])
        
        if car_vin in ['nan', 'NaN']:
            vendor = str(df['vehicle_manufacturer'].iloc[row])
            model = str(df['vehicle_model'].iloc[row])
            body_type = str(df['vehicle_category'].iloc[row])
            vehicle = vendor + ' ' + model + ' ' + body_type
            if vehicle in vins.keys():
                car_vin = vins[vehicle][0]
            else:
                car_vin = 'nan'
        else:
            car_vin = car_vin#[1:6]
        df['car_vin'].iloc[row] = car_vin
                
    return df

# %%
#import category_encoders as ce

def create_expert_feats(data):
    
    # # 1 ++ 
    # def modify_car_vin(car_vin):
    #     car_vin = str(car_vin)
    #     if car_vin not in ['nan', 'Nan']:
    #         # Remove excess spaces
    #         car_vin = ''.join(car_vin.split(' '))
    #     else:
    #         return car_vin
    #     if len(car_vin) < 11:
    #         return car_vin
    #     else:
    #         return car_vin[:11]
        
    # data['car_vin'] =  data['car_vin'].apply(modify_car_vin)
    
    data['car_vin'] =  data['car_vin'].apply(lambda x: ''.join(str(x).split(' ')))
    
    data['vehicle_manufacturer'] =  data['vehicle_manufacturer'].apply(lambda x: ''.join(str(x).split(' ')))
  
    data['vehicle_model'] =  data['vehicle_model'].apply(lambda x: ''.join(str(x).split(' ')))
    
    data['vehicle_category'] =  data['vehicle_category'].apply(lambda x: ''.join(str(x).split(' ')))
    
    display(data.head(7))
    
    vin_dict = get_vin_parts(data)
    display(vin_dict)
    data = set_vin_parts(vin_dict, data)

    # 3 +++
    data['car_wearout_ratio'] = 1e6/((2022 - data['vehicle_year'])*data['current_mileage'])
    
    # 4
#     bin_encoder = ce.BinaryEncoder(cols=['vehicle_category'])
#     type_bin = bin_encoder.fit_transform(data['vehicle_category'])
#     data = pd.concat([data, type_bin], axis=1)
    
#     bin_encoder = ce.BinaryEncoder(cols=['vehicle_gearbox_type'])
#     type_bin = bin_encoder.fit_transform(data['vehicle_gearbox_type'])
#     data = pd.concat([data, type_bin], axis=1)
#     # 5
#     dupl_columns = list(data.columns)
#     dupl_columns.remove('row_ID')
    
#     mask = data.duplicated(subset=dupl_columns)
#     car_duplicates = data[mask]
#     print(f'Число найденных дубликатов: {car_duplicates.shape[0]}')
#     data = data.drop_duplicates(subset=dupl_columns)
#     print(f'Результирующее число записей: {data.shape[0]}')

    display(data.head(5))
    return data

# %%
train_data = create_expert_feats(train_data)
#test_data = create_expert_feats(test_data)
# Out:
#    row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 0       0               TOYOTA         Aquas            Sedan
# 1       1        MERCEDES-BENZ          C220            Sedan
# 2       2              HYUNDAI      Veloster        Hatchback
# 3       3              HYUNDAI       SantaFE             Jeep
# 4       4               TOYOTA           CHR             Jeep
# 5       5           MITSUBISHI        Delica             Jeep
# 6       6              HYUNDAI        Tucson             Jeep
#
#    current_mileage  vehicle_year vehicle_gearbox_type doors_cnt  \
# 0           133000          2014            Automatic       4/5
# 1            24500          2010               Manual       4/5
# 2            31000          2016            Tiptronic       2/3
# 3           115459          2015            Automatic       4/5
# 4            18950          2019            Automatic       4/5
# 5           149000          2003            Automatic       4/5
# 6           173600          2013            Automatic       4/5
#
#                   wheels vehicle_color vehicle_interior_color  \
# 0    Right-hand drive          Silver                  Black
# 1           Left wheel         Silver                  Black
# 2           Left wheel         Silver                  Black
# 3           Left wheel           Blue                  Black
# 4           Left wheel          Black                     NaN
# 5    Right-hand drive          Silver                  Black
# 6           Left wheel         Silver                  Black
#
#              car_vin  car_leather_interior deal_type  final_price
# 0                nan                     0  For Sale       3650.0
# 1                nan                     0  For Sale       6800.0
# 2  KMHTC6AE3GU293912                     1  For Sale       6300.0
# 3                nan                     1  For Sale      14488.0
# 4  JTNKHMBX7K1030253                     1  For Sale       5000.0
# 5                nan                     0  For Sale         20.0
# 6                nan                     1  For Sale       7632.0
# {'HYUNDAI Veloster Hatchback': ['KMHTC6A',
#   'KMHT36A',
#   'KMHTG6A',
#   'VIN:KMH',
#   'KMHTH6A'],
#  'TOYOTA CHR Jeep': ['JTNKHMB', 'NMTKHMB'],
#  'MERCEDES-BENZ GLE350 Sedan': ['4JGDA5J',
#   '4JGFB4J',
#   '4JGED6E',
#   '4JGDA6E',
#   '4JGDA5G'],
#  'NISSAN Juke Jeep': ['JN8AF5M', 'JN8DF5M'],
#  'LEXUS GX470 Jeep': ['JTJBT20', 'JTJJM7F', 'JTJBM7F'],
#  'AUDI Q5 Jeep': ['WA1VFCF',
#   'WA1ANAF',
#   'WA1D7AF',
#   'WA1LFAF',
#   'WA1DKAF',
#   'WA1WKAF',
#   'WA1L2AF',
#   'WA1C8AF',
#   'WA1DGAF',
#   'WA1LFCF',
#   'WA1BNAF',
#   'WA1C2AF',
#   'WA1DGCF'],
#  'BMW X5 Jeep': ['5UXZW0C',
#   '5UXKS4C',
#   '5UXZV8C',
#   '5UXZV4C',
#   '5UXKR0C',
#   '5UXJU2C',
#   '5UXKR2C',
#   '5UXFA53',
#   '5UXFF0C',
#   '5UXFF03',
#   '4444',
#   '5UXKT0C',
#   '5UXZV4G',
#   '5UXKR6C',
#   'WBAFB71',
#   'LT75116',
#   '5784336',
#   '5UXCR6C',
#   'SURATEB',
#   'SURATSH',
#   '5UXFE8C',
#   '5YMGY0C',
#   'WBALSO1',
#   '5UXFE43',
#   'FFI64RF',
#   'DFHHSHJ'],
#  'TOYOTA Camry Sedan': ['4T1BD1F',
#   'JTNB11H',
#   '4T4BF1F',
#   '4T1BD1E',
#   '4T1BF1F',
#   '4T1BK1F',
#   '4T1B31H',
#   '4T1B11H',
#   '4T1B61H',
#   '4T1BF3E',
#   '4T1BF1E',
#   '4T1BB3E',
#   '4T1B21H',
#   '4T1BE46',
#   '4T1BB46',
#   '4T1BK3E',
#   'JTNBB46',
#   '4T4BF3E',
#   '4T1BZ1H',
#   'JN8AF5M'],
#  'TOYOTA Highlander Jeep': ['JTEDC3E',
#   'JTEEW41',
#   '5TDBK3E',
#   '5TDDCRF',
#   'JTEJW3E',
#   '5TDZK3E',
#   'JTEEW44',
#   '5TDDK3E',
#   '5TDBKRF',
#   '5TDJZRF',
#   'JTEBC3E',
#   '5TDYK3E',
#   '5TDDGRF'],
#  'VOLKSWAGEN Jetta Sedan': ['3VW267A',
#   '3VWDX7A',
#   '3VWB07A',
#   '3VW1K7A',
#   '3VW467A',
#   '3VWLL7A',
#   '3VWDB7A',
#   '3VWDP7A',
#   '3VWL17A',
#   '3VWD17A',
#   '1FADP3F',
#   '3VWLA7A',
#   '3VWC57B',
#   '3VWSF81',
#   '3VWLZ7A',
#   '3VW2K7A',
#   '3VW4A7A',
#   '3VWD67A',
#   '3VWRZ7A',
#   '3VW3L7A',
#   '3VWDZ7A',
#   '3VWRM71',
#   '3VWD07A',
#   '3VW637A',
#   '3VW2B7A',
#   '3VWB17A',
#   '3VWSF71',
#   '3VWDK7A',
#   '3VWSA29',
#   '1KWKEIE'],
#  'CHEVROLET Volt Hatchback': ['1G1RH6E',
#   '1G1RC6S',
#   '1G1RG6E',
#   '1G1RD6E',
#   '1G1RB6E',
#   '1G1RE6E',
#   '1G1RF6E',
#   '1G1RB6S',
#   '1G1RA6E',
#   '1G1RD6S'],
#  'MERCEDES-BENZ GLA250 Jeep': ['WDCTG4G', 'WDCTG4E'],
#  'LEXUS CT200h Hatchback': ['JTHKD5B'],
#  'MERCEDES-BENZ E350 Sedan': ['WDDHF9C',
#   'WDDHF8H',
#   'WDDHF5K',
#   'WDDKK7D',
#   'WDDHF8J',
#   'WDDHF7H',
#   'WDDHF9A',
#   'WDBUF56',
#   'WDDHF5G',
#   'WDBUF22',
#   'WDDKK5K',
#   'WDBUF87',
#   'WDDHF2E',
#   'WDDKK5G',
#   'WDD2120'],
#  'LEXUS GX460 Jeep': ['JTJJM7F', 'JTJBM7F'],
#  'HYUNDAI Elantra Sedan': ['5NPD74L',
#   '5NPDH4A',
#   'KMHDH4A',
#   'KMHD04L',
#   '5NPD84L',
#   'KMHD74L',
#   'KMHD84L'],
#  'TOYOTA Tacoma Sedan': ['3TMJU4G',
#   '5TFJU4G',
#   '5TFNX4C',
#   '5TFJX4G',
#   '5TFDZ5B',
#   '5TFRZ5C',
#   '3TMCZ5A',
#   '3TMLU4E',
#   '3TMDZ5B',
#   '5TFCZ5A',
#   '3TMAZ5C',
#   '5TFMU4F',
#   '5TFUX4E',
#   '3TMMU4F'],
#  'MERCEDES-BENZ GLA250 Sedan': ['WDCTG4E', 'WDCTG4G'],
#  'TOYOTA Prius Hatchback': ['JTDKN3D',
#   'JTDKARF',
#   'JTDKB20',
#   'JTDKBRF',
#   'JTDKDTB',
#   'AM55644',
#   'JTDZN3E',
#   'JYDKN3D',
#   'JTDKB2O',
#   'JTDNK3D'],
#  'SUBARU Forester Jeep': ['JF2SHAE',
#   'JF2SJAX',
#   'JF2SHAB',
#   'JF2SJAD',
#   'JF2SHBB',
#   'JF2SJAH',
#   'JF2SJGX',
#   'JF2SJAE',
#   'JF2SJAP',
#   'JF2SHBE',
#   'JF2SJGD',
#   'JF2SJGM',
#   'JF2SJAG',
#   'JF2SHAC',
#   'JF2SJAA',
#   'JF2SHGA',
#   'JF2SHGG',
#   'VIN:JF2',
#   'JF2SJAB',
#   'JF2SH6C',
#   'JF2SHBD',
#   'JF2SJCH',
#   'JF2SJAR',
#   'JF2SH6B'],
#  'LEXUS GX470 Sedan': ['JTJJM7F', 'JTJBM7F', 'JTJBT20'],
#  'MERCEDES-BENZ E400 Sedan': ['WDD1K6F', 'WDD1J6F'],
#  'MAZDA Mx-5Miata Cabriolet': ['JM1NDAB'],
#  'MINI CooperSCabrio Hatchback': ['WMWXU3C', 'WMWLU5C'],
#  'HYUNDAI Sonata Sedan': ['KMHEC4A',
#   '5NPEC4A',
#   'KMHE24L',
#   '5NPE24A',
#   'KMHE54L',
#   '5NPE34A',
#   '5NPEB4A',
#   'KMHE34L',
#   '12345'],
#  'FORD Escape Sedan': ['1FMCU02',
#   '1FMCU0G',
#   '1FMCU49',
#   '1FMCU4K',
#   '1FMCU9D',
#   '1FMCU59',
#   '1FMCU9G',
#   '1FMCU5K'],
#  'SUBARU WRX Sedan': ['JF1VA1E', 'JF1VA1J'],
#  'LEXUS IS250 Sedan': ['JTHBF1D', 'JTHBF5C', 'JTHBK26'],
#  'FORD Fusion Sedan': ['3FA6P0P',
#   '3FA6P0L',
#   '3FA6P0K',
#   '3FA6P0R',
#   '3FA6P0H',
#   '3FA6P0U',
#   '3FA6P0D',
#   '3FA6POL',
#   '3FADP0L',
#   '3FADPOL',
#   '3FA6P0S',
#   '3FA6P0G',
#   '3FA6POP',
#   '3FAHP0H',
#   '1FA6P0H',
#   '3FAHP0J',
#   '3FA6POR',
#   '3FA6POH',
#   '1FA6P0G',
#   '3FA6P0T'],
#  'HYUNDAI ElantraRESTAYLING Sedan': ['KMHDH4A'],
#  'AUDI Q3 Sedan': ['WA1BFCF', 'WA1EFCF'],
#  'FORD Escape Jeep': ['1FMCU59',
#   '1FMCU9C',
#   '1FMCU5K',
#   '1FMCU0D',
#   '1FMCU49',
#   '1FMCU4K',
#   '1FMCU0G',
#   '1FMCU9G',
#   '1FMCU0H',
#   '1FMCU94',
#   '1FMCU9E',
#   '1FMCU9H',
#   '111111'],
#  'TOYOTA Tundra Sedan': ['5TFRM5F',
#   '5TFUM5F',
#   '5TFHW5F',
#   '5TFDY5F',
#   '5TFDW5F',
#   '5TFEY5F'],
#  'DODGE Challenger Coupe': ['2G1FE1E',
#   '2C3CDZB',
#   '2C3CDZA',
#   '2C3CDYA',
#   '2C3CDYB',
#   '2C3CDZF',
#   '2C3CDZG',
#   '2C3CDZJ'],
#  'MINI CountrymanS Hatchback': ['WMWZC3C', 'WMWZC5C'],
#  'MERCEDES-BENZ E300 Sedan': ['WDDZF4J',
#   'WDDZF4K',
#   'WDDZF6J',
#   'WDD1K6F',
#   '1234455'],
#  'CHEVROLET Cruze Sedan': ['1G1PC5S',
#   '1G1PE5S',
#   '1G1BC5S',
#   '1G1BE5S',
#   '1G1PH5S',
#   '1G1PD5S',
#   '1G1PG5S',
#   '1G1PF5S',
#   '1G1PA5S',
#   '4S4BRBA',
#   '1G1PB5S',
#   '1G1P75S'],
#  'MERCEDES-BENZ ML350 Jeep': ['4JGBB2F',
#   '4JGDA2E',
#   '4JGBB86',
#   '4JGBB22',
#   '4JGDA5H',
#   '4JGBB8G',
#   '4JGDA7D',
#   '4JGBB5G',
#   '4JGDA5J',
#   '4JGAB57'],
#  'BMW 740 Sedan': ['WBAKB4C', 'WBAYA6C', 'WBAHL61', 'WBAKA4C'],
#  'BMW X6 Jeep': ['5UXFG8C',
#   '5UXKU6C',
#   '5YMGZ0C',
#   '5UXKU2C',
#   '5UXFG2C',
#   'WBAFG81',
#   '5UXFG83',
#   '5UXFG4C',
#   '5YMKW8C'],
#  'TOYOTA Priushybrid Sedan': ['JTDKN3D'],
#  'TOYOTA Tacoma Jeep': ['5TFCZ5A',
#   '3TMAZ5C',
#   '5TFJX4G',
#   '5TFNX4C',
#   '3TMMU4F',
#   '5TFAX5G',
#   '3TMCZ5A',
#   '5TFDZ5B',
#   '5TFAZ5C'],
#  'BMW 328 Sedan': ['WBA3C1C',
#   'WBA8E9C',
#   'WBA3A5G',
#   'WBA3B3C',
#   'WBAPH7C',
#   'WBA3B5C',
#   'WBA3B5G',
#   'WBA3A5C',
#   'WBA3B3G',
#   'WBA8E9G',
#   'WBAPK7C'],
#  'MITSUBISHI OutlanderSPORT Jeep': ['4A4AP3A',
#   'JA4AP4A',
#   'JA4AP3A',
#   '4A4AR3A'],
#  'TOYOTA Avalon Sedan': ['4T1BD1E', '4T1BK1E'],
#  'BMW X1 Jeep': ['WBXHT3C', 'WBAVM1C', 'WBAVL1C', 'WBXHU7C'],
#  'NISSAN Note Hatchback': ['1234544', '5989795'],
#  'MERCEDES-BENZ E350 Jeep': ['4JGBB5G'],
#  'TOYOTA Highlander Sedan': ['JTEEW41',
#   'JTEES43',
#   '5TDBK3E',
#   '5TDJKRF',
#   'JTEJW3E',
#   'JTEEW44',
#   '5TDZK3E',
#   'JTEDC3E'],
#  'LEXUS HS250h Sedan': ['JTHBB1B'],
#  'LEXUS NX200 Jeep': ['JTJBJRB', 'JTJBARB', 'JTJYARB', 'JTJBERB'],
#  'LEXUS RX450 Jeep': ['2T2BK1B',
#   '2T2BGMC',
#   'JTJZB1B',
#   'JTJBC1B',
#   '2T2BZMC',
#   '2T2ZZMC',
#   '2T2ZK1B',
#   '2T2GK31',
#   '2T2BC1B'],
#  'JEEP Wrangler Jeep': ['1J4BA3H', '1C4BJWC'],
#  'LEXUS RCF Coupe': ['JTHHE5B', 'JTHSE5B', 'JTHHA5B'],
#  'HYUNDAI Tucson Sedan': ['KM8JUCA', 'KM8JU3A', 'KM8J33A', 'KM8J23A'],
#  'TOYOTA PriusC Hatchback': ['JTDKDTB', 'VIN:JTD'],
#  'AUDI A4 Sedan': ['WAUAFAF',
#   'WAUFFAF',
#   'WAUHFBF',
#   'WAUAF78',
#   'WAUANAF',
#   'WAUENAF',
#   'WAUEFAF',
#   'WAUDFAF',
#   'WAUGMAF'],
#  'HONDA Insight Sedan': ['JHMZE2H'],
#  'SUZUKI GrandVitara Jeep': ['AGG2281', 'JS3TD54'],
#  'AUDI A7 Hatchback': ['WAUWGBF', 'WAU2GAF', 'WAUWGAF', 'WAU3GAF', 'WAUYGAF'],
#  'LEXUS RX350 Jeep': ['2T2ZZMC',
#   '2T2BK1B',
#   '2T2ZK1B',
#   'JTJBZMC',
#   '2T2BZMC',
#   'JTJGZKC',
#   '2T2HK31',
#   '2T2HZMA',
#   'JTJBK1B'],
#  'MERCEDES-BENZ R350 Jeep': ['4JGBB86', '4JGCB2F'],
#  'TOYOTA Prius Jeep': ['JTDKN3D'],
#  'MERCEDES-BENZ E350 Coupe': ['WDDKJ5G', 'WDDKJ5K', 'WDDKK5K'],
#  'HYUNDAI ElantraSE Sedan': ['5NPD84L',
#   'KMHD84L',
#   '5NPD74L',
#   '5NPDH4A',
#   'KMHD74L'],
#  'BMW 528 Sedan': ['WBAFR1C',
#   'WBA5A7C',
#   'WBANV13',
#   'WBANU5C',
#   'WBAXH5C',
#   'WBAXG5C',
#   'WBANU53',
#   'WBA5A5C'],
#  'MERCEDES-BENZ S550 Sedan': ['WDDUG8F', 'WDDUG8C', 'WDDNG71', 'WDDNG9E'],
#  'VOLKSWAGEN Passat Sedan': ['1VWBM7A',
#   '1VWAT7A',
#   '1VWDT7A',
#   '1VWBA7A',
#   '1VWCM7A',
#   '1VWAH7A',
#   '1VWAP7A',
#   '1VWBT7A',
#   '1VWBH7A',
#   '1VWCV7A',
#   '1VWBP7A',
#   '1VWBS7A',
#   '1VWAS7A',
#   '1VWCS7A',
#   '1VWCN7A',
#   'WVWAK73',
#   '1VWLA7A',
#   'WVWCK73',
#   '1VWCP7A'],
#  'DODGE Avenger Sedan': ['1C3CDZA'],
#  'TOYOTA Prius Sedan': ['JTDKN3D',
#   '111111',
#   'JTDKB20',
#   'JTDKARF',
#   'JTDKDTB',
#   'JTDKBRF',
#   '45785',
#   'JTDZN3E',
#   'OV14264'],
#  'AUDI Q7 Jeep': ['WA1LMAF',
#   'WA1LGBF',
#   'WA1DGAF',
#   'WA1CGAF',
#   'WA1LAAF',
#   'WA1AHAF',
#   'WA1WMAF',
#   'WA1VAAF',
#   'WAUZZZ4',
#   'geocapi',
#   'WA1LGAF'],
#  'MERCEDES-BENZ GLE350 Jeep': ['4JGDA5J',
#   '4JGED6E',
#   '4JGDA5G',
#   '4JGDA5H',
#   '4JGED7F'],
#  'SUBARU XV Sedan': ['JF2GPAW',
#   'JF2GPAD',
#   'JF2GPAC',
#   'JF2GPBK',
#   'JF2GPAP',
#   'JF2GPAG',
#   'JF2GPAS'],
#  'HYUNDAI SantaFE Jeep': ['5NMS2CA',
#   '5XYZUDL',
#   'KM8SR4H',
#   'KM8SM4H',
#   'SXYZUDL',
#   '5NMS53A'],
#  'OPEL AstraG Universal': ['W0L0TGF'],
#  'FORD Fiesta Hatchback': ['3FADP4T', '3FADP4E', '3FADP4F', '3FADP4B'],
#  'AUDI RS7 Hatchback': ['WAUW2AF'],
#  'OPEL Vectra Sedan': ['FHKBHJ', 'WOL0000', '9999', 'WOLOJBF', 'W0L0000'],
#  'BMW 320 Sedan': ['WBA3B1C',
#   'WBA3C3C',
#   'WBA8E1G',
#   'WBA8A3C',
#   'AM57025',
#   'WBAPP11',
#   'WBAVC31'],
#  'FORD Mustang Coupe': ['1ZVBP8A',
#   '1FA6P8C',
#   '1ZVBP8C',
#   '1FATP8U',
#   '1FA6P8T',
#   '1FA6P8A',
#   '1ZVHT80',
#   '2G1FE1E'],
#  'CHEVROLET MalibuLT Sedan': ['1G1ZE5S', '1G1ZD5S'],
#  'MERCEDES-BENZ GL4504MATIC Jeep': ['4JGBF7B'],
#  'TOYOTA Tacoma Pickup': ['3TMMU4F',
#   '5TEUU4E',
#   '5TFTU4C',
#   '5TFTX4G',
#   '5TFNX4C',
#   '5TFUU4E',
#   '3TMCZ5A',
#   '5TFUX4E'],
#  'BMW 535 Sedan': ['WBAFR7C',
#   'WBAXA5C',
#   'WBAFV3C',
#   'WBAFU7C',
#   'WBA5B3C',
#   'WD12CD1',
#   'WBA5B1C',
#   'WBANW13'],
#  'TOYOTA Sienna Minivan': ['5TDDZ3D',
#   '5TDYK3D',
#   '5TDZZ3D',
#   '5TDKK3D',
#   '5TDJK3D',
#   '5TDDK3D',
#   '5TDXK3D'],
#  'AUDI A6C7 Sedan': ['WAUGGAF'],
#  'FORD F150 Jeep': ['1FTEW1E'],
#  'CHEVROLET Camaro Sedan': ['2G1FK3D',
#   '1G1FH1R',
#   '1G1FH3D',
#   '1G1FJ1R',
#   '2G1FD1E'],
#  'HYUNDAI Tucson Jeep': ['KM8JUCA',
#   'KM8JU3A',
#   'KM8J33A',
#   'KM8J3CA',
#   'KM8JT3A',
#   'KM8J2CA',
#   'KMHJN81',
#   'KM8J23A'],
#  'AUDI Q7sport Jeep': ['WA1LGAF'],
#  'HYUNDAI Elantra Hatchback': ['5NPDH4A', 'KMHD35L', 'KMHDH4A'],
#  'FORD Fusionse Sedan': ['3FA6P0H'],
#  'TOYOTA RAV4 Jeep': ['JTMRFRE',
#   'JTMBFRE',
#   '2T3RFRE',
#   'JTMBF4D',
#   '2T3BF4D',
#   'JTMJFRE',
#   '2T3ZF4D',
#   '2T3BFRE',
#   'THBDJS',
#   'JTMDFRE',
#   '2T3ZFRE',
#   'JTMRJRE',
#   '2T3F1RF',
#   'JTMDJRE',
#   '2T3YFRE',
#   '2T3DFRE',
#   '2T3P1RF',
#   'JTMWFRE',
#   '2T3JF4D',
#   '2T3K1RF',
#   'JTMBA31',
#   'JTMNFRE',
#   'JTMZFRE'],
#  'TOYOTA PriusC Sedan': ['JTDKDTB'],
#  'TOYOTA Camrysport Sedan': ['4T1BF1F'],
#  'PORSCHE Cayenne Jeep': ['WP1AA2A',
#   'WP1AD2A',
#   'WP1AE2A',
#   'WP1AB2A',
#   'WP1AF2A',
#   'WP1AA29',
#   'WPIZZZ9'],
#  'PORSCHE 911 Coupe': ['WP0CB2A', 'WP0AA2A', 'WP0AB2A', 'WP0AF2A', 'WP0CA2A'],
#  'MAZDA 626 Sedan': ['1YVGF22', 'JMZGF14'],
#  'KIA Optima Sedan': ['5XXGR4A',
#   'BV34927',
#   '5XXGN4A',
#   'KNAGM4A',
#   '5XXGM4A',
#   'KNAGT4L',
#   '5XXGT4L',
#   'KNAGM4D',
#   '4132E88',
#   'KNAGN4A',
#   '5XXGU4L',
#   '3KPFL4A'],
#  'HYUNDAI Elantra Jeep': ['KMHD74L', '5NPDH4A', 'KMHDH4A'],
#  'TOYOTA HighlanderHYBRID Jeep': ['JTEEW44'],
#  'FORD C-MAXSEL Hatchback': ['1FADP5B'],
#  'PORSCHE Panamera Sedan': ['WP0AB2A', 'WP0AA2A', 'WP0AF2A', 'WP0AD2A'],
#  'LEXUS LS460 Sedan': ['JTHCL5E', 'JTHBL5E', 'JTHBL46'],
#  'FORD FiestaSE Sedan': ['3FADP4B'],
#  'SUBARU Impreza Sedan': ['JF1GPAZ',
#   'JF1GJAD',
#   'JF1GPAA',
#   'JF1GPAD',
#   'JF1GV7F',
#   'JF1GV8J',
#   'JF1GV7E',
#   'JF1GJAB',
#   'JF1GPAW',
#   'JF1GJAC',
#   'JF1GR7E',
#   'JF1GPAK',
#   'HEHSHSH'],
#  'HYUNDAI TucsonSE Jeep': ['KM8J3CA', 'KM8J23A'],
#  'CHEVROLET CruzeLT Sedan': ['1G1BE5S', '1G1PF5S', '1G1BD5S', '1G1PC5S'],
#  'TOYOTA PriusV Hatchback': ['JTDZN3E'],
#  'BMW 335 Coupe': ['WBAKF9C'],
#  'DODGE Ramcharger Sedan': ['2C3CDXH'],
#  'MITSUBISHI OutlanderES Jeep': ['JA4AD2A'],
#  'KIA Sorento Jeep': ['5XYKTDA', '5XYKT4A', '5XYKTCA', '5XYKT3A'],
#  'SUBARU XV Jeep': ['JF2GPAC',
#   'JF2GPAW',
#   'JF2GPAG',
#   'JF2GPAV',
#   'JF2GPAD',
#   'JF2GPBK',
#   'JF2GPBC',
#   'JF2GPAS',
#   'JF2GPAM',
#   'JF2GPAK'],
#  'SUZUKI SX4 Sedan': ['JS2YB5A', 'JS2YC5A'],
#  'FORD Fiesta Sedan': ['3FADP4A', '3FADP4B'],
#  'PORSCHE macan Jeep': ['WP1AB2A', 'WP1AA2A', 'WP1AG2A'],
#  'TOYOTA Tundra Jeep': ['5TFUY5F', '5TFAW5F', '5TFDW5F', '5TFUM5F', '5TFRY5F'],
#  'FORD FocusSE Sedan': ['1FADP3F', '1FAHP3F'],
#  'MERCEDES-BENZ ML500 Jeep': ['4JGAB75', '4JGBB75'],
#  'BMW 328 Coupe': ['1234', 'WBAWB3C', '2198'],
#  'NISSAN Altima Coupe': ['1N4AL2A'],
#  'VOLKSWAGEN JettaSE Sedan': ['3VWD17A', '3VWDB7A', '3VWD67A'],
#  'BMW 335 Sedan': ['WBADX7C',
#   'WBAPL5C',
#   'WBA3A9G',
#   'WBA3A9C',
#   'WBA3B9C',
#   'VBA3B9C'],
#  'FORD Focus Sedan': ['1FADP3F',
#   '1FAHP3F',
#   '3FA6P0L',
#   '1FAHP3H',
#   '1FADP3K',
#   '1FADP3E'],
#  'AUDI Q7 Sedan': ['WA1WMAF', 'WA1LAAF', 'WA1VAAF', 'WA1CGAF'],
#  'FORD Focus Universal': ['WFONXXW', '1FAHP3H'],
#  'NISSAN Juke Sedan': ['JN8AF5M'],
#  'CHEVROLET Camaro Coupe': ['2G1FK1E',
#   '2G1FD1E',
#   '2G1FA1E',
#   '2G1FE1E',
#   '1G1FE1R',
#   '2G1FB1E',
#   '2G1FG1E',
#   '2G1FC1E',
#   '1G1FG1R',
#   '2G1FT1E'],
#  'AUDI A6 Sedan': ['WAUDG74',
#   'WAUGFAF',
#   'WAUFGAF',
#   'WAUBGAF',
#   'WAUE8AF',
#   'WAUDH74'],
#  'LEXUS CT200h Sedan': ['JTHKD5B'],
#  'LEXUS RX400 Jeep': ['JTJHW31', '2T2GK31', '2T2HK31', '2T2BK1B', '2T2BZMC'],
#  'CHEVROLET Volt Sedan': ['1G1RC6S',
#   '1G1RD6S',
#   '1G1RH6E',
#   '1G1RB6E',
#   '1G1RB6S',
#   '1G1RD6E',
#   '1G1RE6E'],
#  'HYUNDAI SonataLimited Sedan': ['KMHEC4A', '5NPEC4A'],
#  'LEXUS GX460 Sedan': ['JTJBM7F', 'JTJJM7F'],
#  'TOYOTA CorollaLE Sedan': ['5YFBURH', 'JTDBU4E'],
#  'FIAT 500Turbo Hatchback': ['3C3CFFK'],
#  'CHEVROLET Cruze Hatchback': ['3G1BE6S', '3G1BF6S'],
#  'HONDA Civic Sedan': ['2HGFC2E',
#   'JHMFB4F',
#   '19XFB4F',
#   '19XFB2F',
#   '26849E7',
#   '2HGFB6E',
#   'JHMFA36',
#   'JHMFA3F',
#   '2HGFB2F',
#   '19XFB5F'],
#  'HONDA FIT Hatchback': ['JHMGE8H', 'JHMGK5H', 'JHMGE88', '3HGGK5H'],
#  'BMW X5 Sedan': ['5UXZW0C', '5UXZV8C', '5UXKR6C', '5UXFE43'],
#  'JEEP Liberty Jeep': ['1C4PJMA', '1J4GL58', '1J4PN2G'],
#  'MAZDA CX-9 Sedan': ['JM3TB3C', 'JM3TB3B', 'JM3TCBD', 'JM3TB2C', 'JM3TCAC'],
#  'SUBARU WRX Jeep': ['JF1VA2L', 'JF1VA1J'],
#  'CHEVROLET Volt Jeep': ['1G1RH6E',
#   '1G1RB6S',
#   '1G1RD6E',
#   '1G1RB6E',
#   '1G1RE6E',
#   '1G1RD6S',
#   '1G1RC6S'],
#  'VOLKSWAGEN Jettasport Sedan': ['3VWDP7A', '3VWD17A'],
#  'FORD C-MAX Hatchback': ['1FADP5A', '1FADP5B', '1FADP5C'],
#  'LEXUS RX400RESTAILING Jeep': ['JTJHW31'],
#  'HYUNDAI AccentSE Hatchback': ['KMHCT5A'],
#  'MERCEDES-BENZ C240 Universal': ['WDB2020'],
#  'LANDROVER RangeRoverSPORT Jeep': ['SALSF2D'],
#  'VAZ 2121(Niva) Jeep': ['XTA2121', '9999157'],
#  'FORD Fusions Sedan': ['3FA6P0G'],
#  'MITSUBISHI Delica Minivan': ['PD6W-10', 'CV5W010'],
#  'MAZDA CX-7 Sedan': ['JM3ER2B'],
#  'BMW 535I Sedan': ['WBA5B1C'],
#  'BMW X5X-Drive Jeep': ['4USFE83'],
#  'SUBARU Impreza Jeep': ['JF1GH6D', 'JF1GPAK', 'JF1GPAA', 'JF1GJAB'],
#  'HONDA Insight Hatchback': ['JHMZE2H'],
#  'TOYOTA CorollaS Sedan': ['2T1BURH', '5YFBURH'],
#  'DODGE Dart Sedan': ['1C3CDFE', '1C3CDFB', '1C3CDFA'],
#  'HYUNDAI Sonata Jeep': ['KMHEC4A'],
#  'HYUNDAI Azera Sedan': ['KMHFH4J'],
#  'BMW 325 Sedan': ['AM56186', 'WBAAV32', '135GFJJ'],
#  'PORSCHE Cayenne Sedan': ['WP1AA2A'],
#  'SUBARU Forester Sedan': ['JF2SHGA', 'JF2SJAG', 'JF2SJAH'],
#  'CHEVROLET VoltPREMIUM Hatchback': ['1G1RH6E'],
#  'NISSAN Leaf Jeep': ['1N4AZ0C'],
#  'MERCEDES-BENZ GLE63AMG Jeep': ['4JGDA7F'],
#  'JEEP GrandCherokee Jeep': ['1C4RJFB',
#   '1J4GZB8',
#   '1C4RJFC',
#   '1C4RJEB',
#   '1C4RJFJ',
#   '1C4RJFD',
#   '1C4NJDE'],
#  'FIAT 500 Sedan': ['3C3CFFK', '3C3CFFA', '3C3CFFB'],
#  'TOYOTA Priusმე-2თაობა Sedan': ['JTDKB20'],
#  'MITSUBISHI Outlandersport Jeep': ['JA4AR3A', '4A4AP3A', 'JA4AP3A'],
#  'MAZDA Mazda3SPORT Sedan': ['3MZBM1U'],
#  'MAZDA CX-5 Jeep': ['JM3KE2B', 'JM3KFBC', 'JM3KE4C', 'JM3KE4B'],
#  'VOLKSWAGEN NEWBeetle Coupe': ['3VWVA7A'],
#  'TOYOTA CamryXLE Sedan': ['4T1BD1F', 'WDC1641', '4T1BF1F'],
#  'MAZDA Mazda3SPORT Hatchback': ['JM1BM1K'],
#  'LEXUS ES300 Sedan': ['JTHBW1G'],
#  'BMW Z43.0 Cabriolet': ['WBABT51'],
#  'LEXUS ES350 Sedan': ['JTHBK1G',
#   'JTHBW1G',
#   '58ABK1G',
#   '58ABZ1B',
#   'JTHBK1E',
#   'JTHBZ1B'],
#  'INFINITI G37 Sedan': ['JN1CV6A'],
#  'BMW 750 Sedan': ['WBAKC8C', 'WBAYE8C', 'WBA7F2C'],
#  'MERCEDES-BENZ 320 Sedan': ['WDBUF65'],
#  'BMW X3 Sedan': ['5UXTR7C'],
#  'MERCEDES-BENZ C180 Coupe': ['WDB2037'],
#  'FORD Focus Hatchback': ['1FAHP3M', '1FADP3K', '1FAHP3K', '1FAHP3N'],
#  'TOYOTA Hilux Pickup': ['5TFCZ5A'],
#  'MERCEDES-BENZ E350BLUETEC Sedan': ['WDDHF2E'],
#  'MINI Countryman Jeep': ['WMWZC3C', 'WMWZC5C'],
#  'KIA SorentoEX Jeep': ['5XYKT4A', '5XYKU3A'],
#  'MERCEDES-BENZ 208 Universal': ['122235'],
#  'MERCEDES-BENZ C63AMG Coupe': ['WDDWJ8G'],
#  'TOYOTA Camry Jeep': ['4T1BD1F', '4T1B31H', '4T1B21H'],
#  'HYUNDAI Sonata2015 Sedan': ['5NPE24A'],
#  'MERCEDES-BENZ GL63AMG Jeep': ['4JGDF7E'],
#  'FORD Mustang Sedan': ['1ZVBP8E', '1FATP8U', '1FA6P8C'],
#  'VOLKSWAGEN JettaTDI Sedan': ['3VW3L7A'],
#  'MERCEDES-BENZ CLA250 Sedan': ['WDDSJ4E'],
#  'LANDROVER Discovery Jeep': ['SALLAAA'],
#  'LANDROVER RangeRover Jeep': ['SALMF11', 'SALGS2K'],
#  'INFINITI Q50 Sedan': ['JN1BV7A', 'JN1EV7A'],
#  'VOLKSWAGEN Golf Hatchback': ['1111', 'WVWNM7A', 'WVWDB7A', '55555'],
#  'MERCEDES-BENZ E3504MATIC Sedan': ['VDDHF8J', 'WDDHF8H'],
#  'OPEL Astra Cabriolet': ['W0L0000'],
#  'BMW 428 Coupe': ['WBA4J1C',
#   'WBA3N7C',
#   'WBA4P1C',
#   'WBA3N9C',
#   'WBA4W3C',
#   'WBA3N3C',
#   'WBA3V5C'],
#  'FORD FusionTITANIUM Sedan': ['3FA6P0R', '3FA6P0K'],
#  'BMW X3 Jeep': ['5UXWX9C',
#   '5UXWX7C',
#   '5UXWZ7C',
#   'WBXPA73',
#   '5UXTR7C',
#   '5UXWX5C',
#   '5UXTR9C',
#   'WBXPC9C'],
#  'MINI Cooper Hatchback': ['WMWSU3C',
#   'WMWXM5C',
#   'WMWZB3C',
#   'WMZYS7C',
#   'WMWMF3C',
#   'WMWMF33',
#   'WMWXU1C',
#   'WMWXS5C'],
#  'BMW X5E70 Jeep': ['5UXFE83'],
#  'FERRARI California Coupe': ['ZFF65LJ', 'ZFF89FP'],
#  'OPEL Corsa Hatchback': ['......'],
#  'AUDI Q5Quattro Jeep': ['WA1LFAF'],
#  'FIAT 500 Hatchback': ['3C3CFFF', '3C3CFFB', '3C3CFFA'],
#  'AUDI A6QUATTRO Sedan': ['WAUZZZ4'],
#  'MERCEDES-BENZ E350ამგ Sedan': ['WDDHF8J'],
#  'AUDI Q5 Sedan': ['WA1DGCF', 'WA1ANAF', 'WA1CMAF', 'WA1D7AF'],
#  'MERCEDES-BENZ C300 Sedan': ['55SWF4J',
#   'WDDGF81',
#   '55SWF4K',
#   'WDDGF8A',
#   'WDDGF5E',
#   'WDDGF8B',
#   'WDDGF54'],
#  'MERCEDES-BENZ Sprinter315CDI Microbus': ['WDB9066'],
#  'VOLKSWAGEN Touareg Jeep': ['WVGEK9B', 'WVGZE77', 'XNXND'],
#  'VOLKSWAGEN PassatSEL Sedan': ['1VWCS7A'],
#  'MERCEDES-BENZ Vito Minivan': ['WDF6382', 'WDF6396', '1234', 'WDF6397'],
#  'MERCEDES-BENZ C250 Sedan': ['WDDGF4H', 'WDB2030'],
#  'INFINITI JX35 Jeep': ['5N1AL0M'],
#  'CHEVROLET CruzeLTRS2014 Sedan': ['1G1PE5S'],
#  'NISSAN Sentra Sedan': ['3N1AB7A'],
#  'TOYOTA PriusV Sedan': ['JTDZN3E'],
#  'VOLKSWAGEN Scirocco Sedan': ['WVWBN7A', 'WVWNP7A'],
#  'HONDA InsightEX Hatchback': ['JHMZE2H'],
#  'MERCEDES-BENZ E280 Sedan': ['WDB2100', 'KAFG'],
#  'LEXUS RX450HYBRID Jeep': ['JTJBC1B'],
#  'MERCEDES-BENZ GL350 Jeep': ['4JGDF2E', '4JGBF2F'],
#  'MERCEDES-BENZ C250W204 Sedan': ['WDDGF4H'],
#  'TOYOTA Tacoma Hatchback': ['3TMJU4G'],
#  'MERCEDES-BENZ E500AVG Sedan': ['WDB2110'],
#  'TOYOTA Camry Coupe': ['4T1BD1F'],
#  'CHEVROLET Malibu Sedan': ['1G11D5R', '1G1ZB5S', '1G1ZE5S', '1G1ZD5S'],
#  'MERCEDES-BENZ G550 Jeep': ['WDCYC6B', 'WDCYC5F', 'WDCYC3H', 'WDCYC3K'],
#  'TOYOTA CamryHYBRID Sedan': ['4T1BD1F', '4T1BB3E'],
#  'FORD Focusse Sedan': ['1FADP3F'],
#  'OPEL Astra Universal': ['HHBKBH', 'W0L0000', 'W0L0AHL'],
#  'HONDA Cr-v Jeep': ['3CZRM3H',
#   '2HKRM4H',
#   '5J6RE4H',
#   'JHLRD78',
#   '5J6RE48',
#   '5J6RM4H',
#   '5J6RM3H'],
#  'SUBARU Legacy Sedan': ['GGW7654', '4S3BMDG', '4S3BNAC'],
#  'MITSUBISHI Outlander Jeep': ['JA4AR3A',
#   'JA4AD2A',
#   'JA4MT31',
#   '4A4AP4A',
#   'JA4AZ3A',
#   'JA4AD3A',
#   '4A4AR3A',
#   'WCW5',
#   'JA4AT2A',
#   '4A4AP3A',
#   'JA4AP4A',
#   'JA4AR4A'],
#  'JEEP GrandCherokee Sedan': ['1C4RJEB', '1C4RJFC', '1C4RJFB'],
#  'FORD FusionHybrid Sedan': ['3FA6POL'],
#  'BMW X5Japan Jeep': ['WBAFE81'],
#  'TOYOTA Aqua Hatchback': ['NHP1060', 'NHP1061'],
#  'MERCEDES-BENZ C200 Sedan': ['WDB2020', 'WDD2050'],
#  'MERCEDES-BENZ CLS55AMG Coupe': ['WDD2J6B', 'WDDUG8G'],
#  'TOYOTA RAV44DRSPOR Jeep': ['JTMBFRE'],
#  'LANDROVER RangeRoverEvoque Jeep': ['SALVR2B', 'SALVP2B', 'SALVP1B'],
#  'TOYOTA Camryse Sedan': ['4T1BF1F', '4T1B11H'],
#  'NISSAN Rogue Jeep': ['JN8AS5M', '5N1AT2M', '5N1ET2M'],
#  'NISSAN X-Trail Jeep': ['Z8NTANT'],
#  'FORD C-MAXTitanium Hatchback': ['1FADP5C'],
#  'JAGUAR XJ6 Sedan': ['SAJWJ1C', 'SAJWA1C'],
#  'TOYOTA Auris Hatchback': ['JTNKARJ'],
#  'MERCEDES-BENZ C250 Coupe': ['WDDGJ4H'],
#  'SSANGYONG REXTONSUPER Jeep': ['KPBFA2A'],
#  'HYUNDAI ElantraGT Hatchback': ['KMHD35L'],
#  'MERCEDES-BENZ CLS550 Sedan': ['WDDLJ7D', 'WDDDJ7C'],
#  'MERCEDES-BENZ CLS63AMG Sedan': ['WDDLJ7G'],
#  'MERCEDES-BENZ CLA250 Hatchback': ['WDDSJ4E'],
#  'KIA Optimahybrid Sedan': ['KNAGM4A'],
#  'HYUNDAI Sonatalimited Sedan': ['5NPEC4A'],
#  'OPEL Vectra Goodswagon': ['W0L0JBF'],
#  'NISSAN JukeNISMO Jeep': ['JN8AF5M'],
#  'HYUNDAI Veloster Coupe': ['KMHTC6A'],
#  'JAGUAR F-type Jeep': ['SAJD51E'],
#  'NISSAN Versa Hatchback': ['3N1BC1C'],
#  'BMW 525tds Sedan': ['WBADF71'],
#  'KIA SportageSX Jeep': ['KNDPCCA', 'KNDPR3A'],
#  'VOLKSWAGEN JettaSEL Sedan': ['3VWLZ7A'],
#  'JEEP PatriotLatitude Jeep': ['1C4NJPF'],
#  'HONDA Hr-vEXL Jeep': ['3CZRU5H'],
#  'BMW 328f30 Sedan': ['WBA3A5C'],
#  'VOLKSWAGEN PassatB7 Sedan': ['1VWAP7A', '1VWBH7A'],
#  'TOYOTA CorollaYARISIA Sedan': ['3MYDLBZ'],
#  'HYUNDAI ElantraLimited Sedan': ['KMHDH4A', '5NPD84L'],
#  'MAZDA 1000 Jeep': ['JM3KFBD', 'JM1DKFB'],
#  'MERCEDES-BENZ ML320 Jeep': ['4JGBB22', '4JGBB25', 'WDC1641'],
#  'TOYOTA PriusV Universal': ['JTDZN3E'],
#  'MERCEDES-BENZ GLA200 Hatchback': ['WDC1569'],
#  'NISSAN Versa Sedan': ['3N1CC1A', '3N1BC1C', '3N1BC1A', '3N1CN7A'],
#  'FORD Transit Goodswagon': ['VR23467'],
#  'TOYOTA CamryHybrid Sedan': ['4T1BD1F'],
#  'FIAT 500 Coupe': ['3C3CFFA', '3C3CFFB', '3C3CFFC'],
#  'HYUNDAI kona Jeep': ['KM8K62A',
#   'KM8K1CA',
#   'KM8K33A',
#   'KM8K22A',
#   'KM8K2CA',
#   'KM8K12A'],
#  'BMW 114 Sedan': ['WBAKB8C', 'WBA5R1C', 'WBA8E1C'],
#  'HONDA Civic Jeep': ['19XFB4F', 'JHMFB4F'],
#  'MERCEDES-BENZ C250luxury Sedan': ['WDDGF4H'],
#  'MAZDA Atenza Hatchback': ['GG3S109'],
#  'TESLA ModelS Hatchback': ['5YJSA1H', '5YJSA1E', '5YJ3E1E'],
#  'DODGE Dakota Pickup': ['1D7RW3G'],
#  'NISSAN Pathfinder Jeep': ['11111', '5N1AR1N', 'VSKJVWR'],
#  'KIA SOUL Jeep': ['KNDJN2A'],
#  'MITSUBISHI Lancer Sedan': ['JA3AU16'],
#  'MAZDA Mazda6 Sedan': ['JM1GJ1V', 'JM1GL1V', 'JM1GJ1W'],
#  'OPEL Astra Hatchback': ['W08AT67', 'WO8AT67', 'W0L0000', 'OV10995'],
#  'TOYOTA Tundra Coupe': ['5TFFY5F'],
#  'MERCEDES-BENZ S350 Cabriolet': ['WDD1K6H'],
#  'BMW 5282.0ტურბო Sedan': ['WBA5A7C'],
#  'TOYOTA Highlanderlimited Jeep': ['JTEJW3E'],
#  'ASTONMARTIN DB7VantageVolante Cabriolet': ['SCFAB42'],
#  'FERRARI EnzoFerrari Coupe': ['ZFF68NH'],
#  'JAGUAR F-pace Jeep': ['SADCA2B', 'SADCK2G'],
#  'BMW 525 Sedan': ['234327', 'WBADT42', 'AM35143', 'WBADD11'],
#  'TOYOTA Corolla Sedan': ['5YFBU4E',
#   '2T1BURH',
#   'EURO4',
#   '5YFBURH',
#   '2T1BU4E',
#   'JTDBU4E',
#   'JTDEBRB'],
#  'MERCEDES-BENZ S500 Sedan': ['3330'],
#  'FORD EcoSport Jeep': ['MAJ3P1T'],
#  'MERCEDES-BENZ Sprinter Microbus': ['OTAR', 'WD3PE8C', 'WDAPE8C'],
#  'CHEVROLET Trax Jeep': ['3GNCJPS'],
#  'FORD Focusse Hatchback': ['1FADP3K'],
#  'VOLKSWAGEN Passatb8 Sedan': ['1VWAT7A'],
#  'TOYOTA 4Runner Jeep': ['JTEBU5J', 'JTNKHMB', 'JTEZU5J', 'NMTKHMB'],
#  'HONDA StepWagon Minivan': ['RG41000'],
#  'LEXUS RX300 Jeep': ['JTJHW31'],
#  'MERCEDES-BENZ ML350superrexton Jeep': ['KPBFA2A'],
#  'BMW 550 Sedan': ['WBAFR9C', 'WBAFU9C', 'WBAKN9C'],
#  'TOYOTA YarisIA Sedan': ['3MYDLBY'],
#  'MERCEDES-BENZ GL550 Jeep': ['4JGDF7D', '4JGBF8G'],
#  'SUZUKI SX4 Jeep': ['JS2YB5A', 'JS2YB41'],
#  'HYUNDAI Tucson2.0 Jeep': ['KM8JT3A'],
#  'MERCEDES-BENZ S63AMG Hatchback': ['WDDUG8J'],
#  'BMW 320IXDRIVE Sedan': ['WBA3C3C'],
#  'TOYOTA CamrySE Sedan': ['4T1B11H', '4T1BF1F', '4T1BD1F', '4T1BE46'],
#  'TOYOTA Priusჰეჩბექი Sedan': ['JTDKN3D'],
#  'NISSAN Altima Sedan': ['6554323',
#   '7886458',
#   '1N4AL3A',
#   '1N4CL21',
#   '1N4CL2A'],
#  'HYUNDAI Elantralimited Sedan': ['5NPD84L', 'KMHDH4A'],
#  'AUDI RS4 Sedan': ['WAUHGCF', 'WAUDGAF'],
#  'CHEVROLET MalibuHybrid Sedan': ['1G1ZF5S'],
#  'MERCEDES-BENZ G63AMG Jeep': ['WDCYC7D'],
#  'MERCEDES-BENZ C230kompresor Sedan': ['WDBRF40'],
#  'MAZDA 1000 Sedan': ['JM3KE2C', 'JM3KE4C'],
#  'CHEVROLET Aveo Sedan': ['KL1TD56'],
#  'MERCEDES-BENZ E320 Sedan': ['WDBUF65', 'WDBUF22', 'WDB2110'],
#  'LEXUS NX300 Jeep': ['JTJYARB', 'JTJGARB', 'JTJBARB'],
#  'BMW X54.8is Jeep': ['5UXFA93'],
#  'FORD C-MAX Universal': ['1FADP5B'],
#  'HONDA FITSPORT Hatchback': ['JHMGE88', 'JHMGE8H'],
#  'BMW 530 Sedan': ['12345', 'WBANA73', 'WBAFW51', 'WBAJA7C'],
#  'AUDI A5 Coupe': ['WAULFAF'],
#  'NISSAN Note Sedan': ['2452KJG', 'GUVFFY'],
#  'CHEVROLET Spark Sedan': ['KL8CB6S'],
#  'MERCEDES-BENZ C180 Sedan': ['2222222', 'WDB2020'],
#  'KIA RIO Hatchback': ['KNADN51'],
#  'HONDA CivicEX Coupe': ['2HGFG3B'],
#  'FORD Fusion1.6 Sedan': ['3FA6P0H'],
#  'FORD EscapeHYBRID Jeep': ['4M2CU39', '1FMCU59'],
#  'CHEVROLET CruzePREMIER Sedan': ['1G1BG5S', '1G1BF5S'],
#  'LEXUS LX570 Jeep': ['JTJHY7A', 'JTJHY00'],
#  'VOLKSWAGEN JettaGLI Sedan': ['3VW4T7A', '3VW4S7A', '3VW5A7A', '3VWFJ71'],
#  'TOYOTA Prius Coupe': ['JTDKN3D'],
#  'OPEL Astra Coupe': ['TYUU'],
#  'BMW i3 Hatchback': ['WBY1Z4C', 'WBY7Z4C', 'WBY1Z2C', 'WBY1Z8C'],
#  'SUBARU Forester2.0XT(TURBO) Jeep': ['JF2SJGD'],
#  'OPEL Vectrac Sedan': ['WOLOZCF'],
#  'MERCEDES-BENZ CLS500 Sedan': ['1010'],
#  'FORD C-MAXPREMIUM Hatchback': ['1FADP5C'],
#  'HYUNDAI SantaFEUltimate Jeep': ['5XYZWDL'],
#  'FIAT 500L Jeep': ['ZFBCFAD'],
#  'NISSAN Leaf Sedan': ['ZE00012'],
#  'SUBARU ImprezaWRX/STILIMITED Sedan': ['JF1VA2Z'],
#  'AUDI A6PREMIUMPLUS Sedan': ['WAUGGAF'],
#  'MERCEDES-BENZ C220 Sedan': ['WDB2030', '2600'],
#  'LEXUS ES300HIBRID Sedan': ['JTHBW1G'],
#  'BMW 735 Sedan': ['WBAGG42'],
#  'LINCOLN MKZ Sedan': ['3LN6L2L', '3LN6L2G'],
#  'KIA Optimaex Sedan': ['5XXGU4L'],
#  'MERCEDES-BENZ E430AVANTGARDE Universal': ['WDB2102'],
#  'MERCEDES-BENZ R320 Jeep': ['4JGBB22'],
#  'MERCEDES-BENZ E36AMG Sedan': ['WDDHF7C'],
#  'KIA Optimaeco Sedan': ['KNAGM4A'],
#  'CHEVROLET Equinox Jeep': ['2GNAXRE'],
#  'FORD FocusSE Hatchback': ['1FADP3K'],
#  'FORD TransitConnectბენზინი Goodswagon': ['NM0LS6E'],
#  'MINI Countryman Cabriolet': ['WMWZC5C'],
#  'MERCEDES-BENZ S63AMG Sedan': ['WDD2210'],
#  'HYUNDAI Accent Sedan': ['KMHCT4A'],
#  'MERCEDES-BENZ C250Amg Sedan': ['WDDGF4H'],
#  'KIA OptimaSxl Sedan': ['5XXGV4L'],
#  'MERCEDES-BENZ SmartFortwo Coupe': ['WMEEJ3B'],
#  'BMW X53.5 Jeep': ['5UXKROG'],
#  'VOLKSWAGEN Jettase Sedan': ['3VWD07A', '3VWDP7A'],
#  'AUDI A4 Jeep': ['WAUENAF'],
#  'HYUNDAI Sonata2.4L Sedan': ['5NPE24A'],
#  'HYUNDAI Ioniq Hatchback': ['KMHC75L'],
#  'AUDI A7 Coupe': ['WAU23BF', 'WAU2GAF'],
#  'CHEVROLET CruzeLTRS Sedan': ['1G1PE5S'],
#  'FORD C-MAXSE Hatchback': ['1FADP5A'],
#  'FIAT 500Abarth Hatchback': ['3C3CFFK'],
#  'HONDA FIT Sedan': ['JHMGE8G'],
#  'LEXUS GS350 Sedan': ['JTHBE1B', 'JTHBZ1B', 'JTHCE1K'],
#  'MERCEDES-BENZ E220 Sedan': ['WDB2100', 'WDF1642', 'WDD2122', 'WDB2110'],
#  'KIA OptimaHYBRID Sedan': ['KNAGM4A', 'KNAGT4L'],
#  'LEXUS IS350 Sedan': ['JTHBE1D', 'JTHCE1D'],
#  'BMW 330 Sedan': ['WBA8D9G'],
#  'AUDI RS6 Sedan': ['WAUFFAF'],
#  'AUDI A8 Sedan': ['WAURVAF', 'WAURMAF'],
#  'CHEVROLET MalibuLTZ Sedan': ['1G11F5S'],
#  'HYUNDAI Elantra2012 Sedan': ['KMHDH4A'],
#  'VOLKSWAGEN CCrline Sedan': ['WVWBP7A'],
#  'MAZDA CX-9 Jeep': ['JM3TCAD', 'JM3TB38'],
#  'FORD Probe Coupe': ['AV30210'],
#  'MERCEDES-BENZ GLE450 Jeep': ['4JGED6E'],
#  'FORD FusionSE Sedan': ['3FA6P0L', '3FA6P0H'],
#  'FORD FocusTITANIUM Sedan': ['1FADP3J'],
#  'MERCEDES-BENZ C230 Sedan': ['WDBRF52', 'WDBRF40'],
#  'SUBARU Outback Jeep': ['4S4BSAN', '4S4BRBC'],
#  'MAZDA 1300 Jeep': ['JM1BL1V', 'JM1BL1U', '3MZBM1U', 'JM1BL1M'],
#  'BMW 650 Sedan': ['WBA6B4C', 'WBA6B2C'],
#  'MAZDA 1300 Sedan': ['JM1BL1L', 'JM1BL1V', 'JM1BM1W'],
#  'CHRYSLER Crossfire Cabriolet': ['1C3AN65'],
#  'FORD C-MAX Sedan': ['1FADP5C', '1FADP5B', '1FADP5A'],
#  'AUDI A3 Sedan': ['WAUKJBF', 'WAUA7HF', 'WAUB8GF'],
#  'BMW M3 Sedan': ['WBS8M9C'],
#  'HYUNDAI Genesis Sedan': ['KMHGN4J'],
#  'TOYOTA CHR Coupe': ['NMTKHMB', 'JTNKHMB'],
#  'BMW X52007 Jeep': ['4USFE43'],
#  'FORD C-MAXC-MAX Sedan': ['1FADP5B'],
#  'OPEL Astra Goodswagon': ['3582090', 'W0L0TGF'],
#  'MERCEDES-BENZ CLS55AMG Sedan': ['WDDLJ6H', 'WDDLJ6F'],
#  'TOYOTA Highlander Coupe': ['JTEDC3E', 'JTEEW44'],
#  'MERCEDES-BENZ ML3504MATIC Jeep': ['4JGDA5H'],
#  'FORD Focus Goodswagon': ['1234567', 'WFOSXXG'],
#  'BMW M6 Sedan': ['WBS6C9C'],
#  'FORD FocusSe Sedan': ['1FADP3F'],
#  'SUZUKI Alto Hatchback': ['ZFA1760'],
#  'TOYOTA CamrySPORT Sedan': ['4T1BF1F'],
#  'TOYOTA Priusprius Hatchback': ['JTDKB20'],
#  'FIAT 124Spider Cabriolet': ['JC1NFAE'],
#  'TOYOTA RAV4hybrid Jeep': ['JTMDJRE'],
#  'BMW 520 Sedan': ['69TFJ'],
#  'BMW 318 Coupe': ['66GGFD8'],
#  'TOYOTA PriusTRIM5 Hatchback': ['JTDKN3D'],
#  'BMW M4 Coupe': ['WBS3R9C', 'WBS3U9C'],
#  'HYUNDAI Accent Jeep': ['KM8K33A'],
#  'VOLKSWAGEN Jettaსასწაფოდ Sedan': ['3VWDZ7A'],
#  'SKODA Octavia Sedan': ['TMBCD21'],
#  'FORD Mustangecoboost Coupe': ['1FA6P8T'],
#  'TESLA ModelS Sedan': ['5YJ3E1E'],
#  'NISSAN Tiida Hatchback': ['5999795', '3N1BC1C'],
#  'BMW X4 Jeep': ['5UXXW3C'],
#  'HONDA CR-Z Hatchback': ['JHMZF1C', 'JHMZF1D'],
#  'VAZ 2106 Sedan': ['W111111', 'RV07541'],
#  'HYUNDAI ElantraLIMITED Sedan': ['5NPDH4A'],
#  'JEEP Patriot Jeep': ['1J4NF1G'],
#  'VOLKSWAGEN PassatB-8 Sedan': ['1VWBT7A'],
#  'BMW Z4 Coupe': ['WBALM5C'],
#  'CHEVROLET Captiva Jeep': ['JTNBB46'],
#  'MERCEDES-BENZ C350 Coupe': ['WDDGJ5H', 'WDDGJ8J'],
#  'BMW 535Diesel Sedan': ['WBAXA5V'],
#  'HONDA Elysion Minivan': ['RR1-150'],
#  'TOYOTA CamrySe Sedan': ['4T1BF1F'],
#  'VOLKSWAGEN Tiguan Jeep': ['WVGBV7A', 'WVGAV7A', 'WVAV3AX'],
#  'HYUNDAI Elantraლიმიტედი Sedan': ['KMHDH4A'],
#  'TOYOTA CamryLE Sedan': ['4T1BF1F', '4T1BD1F'],
#  'MAZDA CX-7 Jeep': ['JM3ER2B', 'JM3ER4C', 'JM3ER29'],
#  'BMW 435CUPE Coupe': ['WBA3R1C'],
#  'KIA Optimahibrid Sedan': ['KNAGM4A'],
#  'FORD Fusion Jeep': ['3FA6P0R'],
#  'AUDI A6Premium Sedan': ['WAUDFAF'],
#  'MAZDA 616 Jeep': ['JM1GL1W', 'JM1GJ1U', 'JM1GL1U', 'JM1GJ1T'],
#  'KIA RIO Sedan': ['KNADM4A'],
#  'VOLVO XC90R-sport Jeep': ['YV1CZ85'],
#  'HONDA FITSport Hatchback': ['JHMGE88'],
#  'HONDA Insight Jeep': ['19XZE4F'],
#  'HONDA FIT Jeep': ['JHMGK5H'],
#  'MERCEDES-BENZ GL350bluetec Jeep': ['4JGBF2F'],
#  'NISSAN Serena Minivan': ['5646'],
#  'INFINITI FX35 Jeep': ['JN8AS05', 'JN8AS1M'],
#  'HYUNDAI IX35 Jeep': ['KMHJT81'],
#  'MERCEDES-BENZ S350 Sedan': ['WDD2210'],
#  'VOLKSWAGEN PassatSE Sedan': ['1VWBT7A', '1VWBP7A'],
#  'NISSAN RogueSL Jeep': ['JN8AS5M'],
#  'BMW M5 Sedan': ['WBSFV9C', 'WBSJF0C', 'WBSNB93'],
#  'HYUNDAI ElantraSe Sedan': ['5NPD84L'],
#  'SUBARU Outback Hatchback': ['4S4BSAC'],
#  'FORD C-MAXPlugin Hatchback': ['1FADP5C'],
#  'BMW 650 Coupe': ['WBALX3C'],
#  'TOYOTA LandCruiser Jeep': ['5TDBY67', 'JTECB09'],
#  'HONDA Odyssey Minivan': ['5FNRL33', '5FNRL5H'],
#  'INFINITI QX70 Jeep': ['JN8CS1M'],
#  'MERCEDES-BENZ CLA2502,0 Sedan': ['WDDSJ4E'],
#  'VOLKSWAGEN Passattdisel Sedan': ['1VWCN7A'],
#  'LEXUS IS200 Sedan': ['JTHBA1D'],
#  'TOYOTA Venza Jeep': ['4T3BA3B'],
#  'MAZDA Mazda3 Hatchback': ['JM1BL1L'],
#  'MERCEDES-BENZ S450 Sedan': ['WDDUG6G'],
#  'TOYOTA CamryHybridXLE Sedan': ['4T1BD1F'],
#  'OPEL Combo Goodswagon': ['00000'],
#  'SUBARU Outbacklimited Jeep': ['4S4BRCC'],
#  'BMW X5 Hatchback': ['5UXFE43'],
#  'MERCEDES-BENZ E220CDI Sedan': ['geocapi'],
#  'HONDA FITsport Hatchback': ['JHMGE8H', 'JHMGE8G'],
#  'MG 3TF135 Cabriolet': ['LNPEF2B'],
#  'CHEVROLET CruzeRS Sedan': ['1G1PG5S', '1G1BG5S'],
#  'MERCEDES-BENZ C250BLUEFIENCE Sedan': ['WDDGF4H'],
#  'TOYOTA Sequoia Jeep': ['5TDBY67'],
#  'FIAT 500Sport Hatchback': ['3C3CFFH'],
#  'MINI Countryman Sedan': ['WMWZC3C'],
#  'SUBARU Forester Universal': ['SF51587'],
#  'JAGUAR Daimler Jeep': ['SADCK2B'],
#  'MERCEDES-BENZ Smart Coupe': ['WMEFJ5D'],
#  'AUDI Q5PREMIUMPLUS Jeep': ['WA1LFAF'],
#  'HYUNDAI ElantraGLS/LIMITED Sedan': ['KMHDH4A'],
#  'PORSCHE Panamera Hatchback': ['WP0AA2A', 'WP0AF2A'],
#  'HYUNDAI Accent Hatchback': ['KMHCT5A'],
#  'HONDA Mobilio Sedan': ['GB21400'],
#  'MERCEDES-BENZ GL350BLUETEC Jeep': ['4JGDF2E'],
#  'BMW 530GT Hatchback': ['WBASP61'],
#  'KIA Forte Sedan': ['KNAFU4A'],
#  'TOYOTA Yaris Sedan': ['3MYDLBZ', '3MYDLBY'],
#  'BMW 318 Hatchback': ['HSHSHS'],
#  'MERCEDES-BENZ GL320bluetec Jeep': ['4JGBF25'],
#  'NISSAN Juke2015 Jeep': ['JN8AF5M'],
#  'HONDA Crossroad Universal': ['RT41001'],
#  'DODGE Caravan Minivan': ['2D4RN3D'],
#  'JAGUAR XF Sedan': ['SAJWA0F', 'SAJBX4G', 'SAJWA0H'],
#  'OPEL Astra Sedan': ['ASTRA', '25786'],
#  'FORD ExplorerTurbojapan Jeep': ['1FM5K7F'],
#  'AUDI Q3 Jeep': ['WA1EFCF', 'WA1BFCF'],
#  'TOYOTA 4Runner Hatchback': ['JTNKARJ'],
#  'HYUNDAI VelosterR-spec Coupe': ['KMHTC6A'],
#  'TOYOTA Camryxle Sedan': ['4T1BD1F'],
#  'TOYOTA Yaris Hatchback': ['JTDJTUD', 'VNKJTUD'],
#  'MERCEDES-BENZ ML300 Jeep': ['4JGDA5G'],
#  'MERCEDES-BENZ ML550 Jeep': ['4JGDA7D'],
#  'TOYOTA RAV4SPORT Jeep': ['2T3RF4D'],
#  'HONDA FITPREMIUM Hatchback': ['JHMGK5H'],
#  'HONDA FIT Minivan': ['701707'],
#  'VOLKSWAGEN Jettahybrid Sedan': ['3VW637A'],
#  'BMW X33.5i Jeep': ['5UXWX7C'],
#  'FIAT 500turbo Hatchback': ['3C3CFFH'],
#  'JEEP Compass Jeep': ['3C4NJDA'],
#  'HYUNDAI TucsonSe Jeep': ['KM8J33A'],
#  'VOLKSWAGEN PassatS Sedan': ['1VWAT7A'],
#  'MERCEDES-BENZ Viano Minivan': ['WDF6397'],
#  'CHEVROLET Voltrestailingi Hatchback': ['1G1RD6E'],
#  'LANDROVER LandRoverSport Jeep': ['SALLSAA'],
#  'MERCEDES-BENZ GL450 Jeep': ['4JGDF7C', '4JGBF71', '4JGBF7B', '4JGDF6E'],
#  'AUDI A6premiumplus Sedan': ['WAUGGAF'],
#  'MERCEDES-BENZ 270 Jeep': ['FDGG'],
#  'MERCEDES-BENZ CLS550550 Sedan': ['WDDDJ7C'],
#  'MAZDA CX-5Touring Jeep': ['JM3KE2C'],
#  'KIA Optimalx Sedan': ['5XXGT4L'],
#  'FIAT 500X Jeep': ['ZFBCFXD', 'ZFBCFYC'],
#  'BUICK Encore Jeep': ['KL4CJBS', 'KL4CJAS'],
#  'MITSUBISHI Montero Jeep': ['JA4NW31'],
#  'CHEVROLET Cruzesonic Sedan': ['1G1JE5S'],
#  'CADILLAC ATS Sedan': ['1G6AA5R'],
#  'MERCEDES-BENZ Smart Hatchback': ['WME4513'],
#  'BMW 330 Coupe': ['4160287', 'WBAKE5C'],
#  'HYUNDAI SonataSE Sedan': ['5NPE24A'],
#  'TOYOTA AvalonLIMITED Sedan': ['4T1BD1E'],
#  'BMW 335D Sedan': ['WBAPN7C'],
#  'FORD EcoSportSE Jeep': ['MAJ6P1U'],
#  'TOYOTA Priusplug-in Hatchback': ['JTDKN3D'],
#  'MERCEDES-BENZ Sprinter Goodswagon': ['WD3PE8C'],
#  'VOLKSWAGEN GTIJetta Sedan': ['3VWFJ71'],
#  'TOYOTA Camry Hatchback': ['4T1BD1F'],
#  'LINCOLN MKZhybrid Sedan': ['3LN6L2L'],
#  'HYUNDAI AccentSE Sedan': ['KMHCT4A'],
#  'MERCEDES-BENZ A160 Hatchback': ['WDB1681', 'WDD1680'],
#  'FORD Escape3.0 Jeep': ['1FMCU9D'],
#  'TOYOTA VOXY Minivan': ['XACHI', 'BV73838'],
#  'TOYOTA Vitz Hatchback': ['SCP1300'],
#  'BMW X535d Jeep': ['5UXZW0C'],
#  'HYUNDAI Sonatahybrid Sedan': ['KMHEC4A'],
#  'MERCEDES-BENZ GLK350 Jeep': ['WDCGG8H', 'WDCGG5H'],
#  'GREATWALL C30 Sedan': ['LGWEE2K'],
#  'KIA OptimaEX Sedan': ['KNAGN4A', '5XXGN4A'],
#  'JAGUAR S-type Coupe': ['SAJWA6E'],
#  'TOYOTA Prius Universal': ['JTDZN3E'],
#  'MINI Clubman Hatchback': ['WMWZF3C'],
#  'KIA SOUL Hatchback': ['KNDJN2A'],
#  'FORD Focustitanium Hatchback': ['1FADP3N'],
#  'BMW 320XI Sedan': ['WBA8E5G'],
#  'FORD C-MAXSe Hatchback': ['1FADP5A'],
#  'MITSUBISHI EclipseES Jeep': ['JA4AT3A'],
#  'FIAT 500CLounge Cabriolet': ['3C3CFFE'],
#  'MERCEDES-BENZ E400 Cabriolet': ['WDDKK6F'],
#  'LEXUS IS300 Sedan': ['JTHCM1D'],
#  'INFINITI QX50 Jeep': ['3PCAJ5M', 'JN1BJ0R'],
#  'LINCOLN Navigator Jeep': ['5LMFU28', '5LMPU28'],
#  'MERCEDES-BENZ C350 Sedan': ['WDDGF56', 'WDDGF5H'],
#  'INFINITI Q60 Coupe': ['JN1CV6E'],
#  'FIAT 500GUCCI Cabriolet': ['3C3CFFE'],
#  'SUBARU Impreza Coupe': ['JF1GPAK'],
#  'LEXUS HS250hშშ Sedan': ['JTHBB1B'],
#  'MINI Cooper Sedan': ['WMWML3C'],
#  'HONDA Civic Coupe': ['2HGFG12'],
#  'SUBARU ImprezaSport Hatchback': ['4S3GTAL'],
#  'TOYOTA RAV4 Sedan': ['JTMZFRE', '2T3JF4D', '2T3BFRE'],
#  'MERCEDES-BENZ S55 Sedan': ['WDD2211'],
#  'NISSAN X-Terra Jeep': ['5N1AN08'],
#  'FORD EscapeSE Jeep': ['1FMCU9G'],
#  'AUDI Q7S-Line Jeep': ['WA1EY74'],
#  'MITSUBISHI OutlanderSE Jeep': ['JA4AP3A'],
#  'FIAT 500 Jeep': ['3C3CFFB', '3C3CFFK', '3C3CFFA'],
#  'NISSAN KicksSR-line Jeep': ['3N1CP5C'],
#  'MERCEDES-BENZ 230 Sedan': ['IPI648'],
#  'HYUNDAI TucsonLIMITED Jeep': ['KM8J33A'],
#  'NISSAN Pathfinder Sedan': ['5N1AR1N'],
#  'MAZDA Mazda3 Sedan': ['JM1BK12', '3MZBM1U', 'JM1BM1U'],
#  'BMW 428i Coupe': ['WBA3N3C'],
#  'AUDI 100 Jeep': ['WA1CGAF'],
#  'DODGE Caliber Hatchback': ['1B3CB4H', '1B3CB3H', '1B3CB5H'],
#  'HONDA InsightTOURING Sedan': ['19XZE4F'],
#  'LEXUS IS350 Cabriolet': ['JTHFE2C'],
#  'INFINITI M37 Sedan': ['JN1BY1A'],
#  'SKODA Rapid Sedan': ['TMBED2N'],
#  'FORD MustangPremium Coupe': ['1FA6P8T'],
#  'HONDA Hr-v Jeep': ['3CZRU6H', '3CZRU5H'],
#  'VOLKSWAGEN Passat2.0tfsi Sedan': ['WVWAK73'],
#  'MERCEDES-BENZ CLK320 Coupe': ['WDB2083'],
#  'MERCEDES-BENZ E350AMG Sedan': ['WDD2120', 'WDDHF8H'],
#  'INFINITI EX30 Jeep': ['SJKCH5C', 'JN1AJ0H'],
#  'NISSAN JukeNismoRS Jeep': ['JN8DF5M'],
#  'FORD Transit Microbus': ['WFOVXXG', '1234556', 'TY53533', 'WFOLXX'],
#  'TOYOTA PriusCYARISIA Sedan': ['3MYDLBZ'],
#  'MITSUBISHI Eclipse Coupe': ['geocapi'],
#  'BMW 320I Sedan': ['WBA3B1C'],
#  'TOYOTA Corolla Hatchback': ['JTNKARJ'],
#  'VOLKSWAGEN GolfTDI Hatchback': ['WVWMM7A', '3VWRA7A'],
#  'SUZUKI Kizashi Sedan': ['JS2RE9A'],
#  'SUBARU B9Tribeca Jeep': ['4S4WX86'],
#  'KIA Sportage Jeep': ['KNDPBCA', 'KNAPB81', 'KNDPB3A', 'KNDPM3A'],
#  'AUDI Q5 Coupe': ['WA1BNAF'],
#  'TOYOTA LandCruiser Pickup': ['JTFLB71'],
#  'FIAT 500Sport Coupe': ['3C3CFFB'],
#  'CHEVROLET CruzeLS Sedan': ['1G1BC5S'],
#  'JEEP CompassLatitude Jeep': ['1C4NJDE'],
#  'BMW X5M/S Jeep': ['5UXZV4C'],
#  'VOLKSWAGEN TiguanSE Jeep': ['WVGAV7A'],
#  'MINI Countryman Hatchback': ['WMWZC5C'],
#  'MERCEDES-BENZ S320 Sedan': ['90000'],
#  'FORD FusionEcoboost Sedan': ['3FA6P0H'],
#  'HYUNDAI LantraLIMITED Sedan': ['5NPD84L'],
#  'TOYOTA PriusPlugin Sedan': ['JTDKN3D'],
#  'HYUNDAI Genesis Coupe': ['KMHHU6K'],
#  'BMW 435 Coupe': ['WBA3R1C', 'WBA3R5C'],
#  'MITSUBISHI Mirage2019 Sedan': ['ML32F3F'],
#  'PORSCHE Boxster Coupe': ['WP0CA2A', 'WP0CB2A'],
#  'MITSUBISHI OutlanderSport Jeep': ['4A4AP3A', 'JA4AP3A'],
#  'KIA OptimaHybrid Sedan': ['KNAGM4A'],
#  'JAGUAR F-type Coupe': ['SAJWA6E', 'SAJD51E'],
#  'MITSUBISHI Pajero Jeep': ['JMY0RV2'],
#  'TOYOTA 4Runner Sedan': ['NMTKHMB', '3MYDLBZ'],
#  'HONDA Hr-vEX Jeep': ['3CZRU5H'],
#  'SUBARU ForesterXT Hatchback': ['JF2SJGW'],
#  'DODGE DakotaV8magnum Pickup': ['1B7HG38'],
#  'BMW 535ixDrive Sedan': ['WBAFU7C'],
#  'JAGUAR XJ Sedan': ['SAJAR4B'],
#  'LEXUS RX400hybrid Jeep': ['JTJHW31'],
#  'DODGE Durango Jeep': ['1D4RE4G'],
#  'OPEL CrosslandX Jeep': ['6547'],
#  'BMW M4 Cabriolet': ['WBS3U9C'],
#  'JAGUAR E-pace Jeep': ['SADFJ2F', 'SADCJ2B', 'SADCK2G'],
#  'KIA RIOlx Hatchback': ['KNADM5A'],
#  'FORD TransitConnect Microbus': ['WFOHXXG'],
#  'MERCEDES-BENZ C400 Sedan': ['55SWF6G'],
#  'CHEVROLET Cruzestrocna Sedan': ['1G1PC5S'],
#  'OPEL Vectra Hatchback': ['BV32153'],
#  'SUBARU Outback Universal': ['4S4BRBC', 'BP90196', '4S4BREC'],
#  'CHEVROLET Camaro Cabriolet': ['2G1FB3D'],
#  'CHEVROLET CamaroLS Coupe': ['2G1FE1E'],
#  'MERCEDES-BENZ GLE400Coupe,AMGKit Jeep': ['WDC2923'],
#  'AUDI S6 Sedan': ['WAUBNBF'],
#  'MERCEDES-BENZ C250AMG Coupe': ['WDDGJ4H'],
#  'SUBARU Crosstrek Jeep': ['JF2GTAB'],
#  'BMW X535D Jeep': ['5UXFF03', '5UXZW0C'],
#  'MINI Cooper Coupe': ['WMWSU3C', 'WMWMF73'],
#  'TOYOTA Corolla04 Sedan': ['5YFBU4E'],
#  'NISSAN JukeSVAWD Jeep': ['JN8AF5M'],
#  'HYUNDAI konaSEL Jeep': ['KM8K6CA'],
#  'DAIHATSU Terios Jeep': ['VFGUTF?'],
#  'CHEVROLET VoltPremier Hatchback': ['1G1RD6S'],
#  'OPEL VectraC Universal': ['geocapi'],
#  'HONDA FITLX Hatchback': ['3HGGK5H'],
#  'LEXUS NX200 Sedan': ['JTJYWRB', 'JTJBARB'],
#  'MERCEDES-BENZ ML350sport Jeep': ['4JGBB5G'],
#  'TOYOTA CamryXLEHYBRID Sedan': ['4T1BD1F'],
#  'HYUNDAI SonataLIMITED Sedan': ['KMHEC4A', '5NPEC4A'],
#  'TOYOTA PriusVHYBRID Hatchback': ['JTDZN3E'],
#  'VOLKSWAGEN Golf Coupe': ['1234'],
#  'INFINITI QX60 Jeep': ['5N1AL0M', '5N1DL0M'],
#  'TOYOTA CHR Hatchback': ['NMTKHMB'],
#  'AUDI S3 Sedan': ['WAUB1GF'],
#  'FORD FusionHYBRIDSE Sedan': ['3FA6P0L'],
#  'MERCEDES-BENZ A220 Sedan': ['WDD3G4E'],
#  'VOLKSWAGEN RoutanSEL Minivan': ['2V4RW5D'],
#  'NISSAN Fuga Sedan': ['89935BK'],
#  'NISSAN Murano Jeep': ['JN8AZ18'],
#  'FORD Escapeმერკურიმერინერი Jeep': ['4M2CU39'],
#  'TOYOTA Priusჯბლდაჰედაპი Hatchback': ['JTDKN3D'],
#  'BMW 135 Sedan': ['WBAFR7C'],
#  'BMW 328Mpackage Sedan': ['WBA3C1C'],
#  'SEAT Toledo Sedan': ['5994290'],
#  'MINI CooperF-56 Coupe': ['WMWXM5C'],
#  'CHEVROLET CruzeLT Hatchback': ['3G1BE6S'],
#  'TOYOTA LandCruiserPrado Jeep': ['JTEBL29', 'JTEBX3F'],
#  'VOLKSWAGEN Touran Minivan': ['WVGZZZ1'],
#  'HONDA CivicEX Sedan': ['19XFB2F', '19XFC2F'],
#  'CHRYSLER 200 Sedan': ['1C3CCCA'],
#  'BMW 528i Sedan': ['WBAXG5C'],
#  'NISSAN KicksSR Jeep': ['3N1CP5C'],
#  'LEXUS CT200hFsport Hatchback': ['JTHKD5B'],
#  'CADILLAC ATSLUXURY Sedan': ['1G6A95S'],
#  'CHEVROLET Spark Hatchback': ['KLYMA48', 'KL8CF6S'],
#  'MINI Cooper Cabriolet': ['WMWZN3C'],
#  'MERCEDES-BENZ A140 Jeep': ['WDC0G4K'],
#  'KIA OptimaECO Sedan': ['KNAGM4A'],
#  'HYUNDAI TucsonLimited Jeep': ['KM8J3CA'],
#  'AUDI R8 Coupe': ['WUAKBAF'],
#  'MERCEDES-BENZ ML250 Jeep': ['4JGDA0E'],
#  'MERCEDES-BENZ GLK250 Jeep': ['WDCGG0E'],
#  'SUBARU Crosstrek Hatchback': ['JF2GPAV', 'JF2GPBP'],
#  'BMW 335335i Sedan': ['WBAVB73'],
#  'RENAULT KangooWaggon Goodswagon': ['VF1FW1A'],
#  'MERCEDES-BENZ E240 Sedan': ['WDB2100'],
#  'CHEVROLET Sonic Hatchback': ['1G1JA6S'],
#  'TOYOTA CamrySport Sedan': ['4T1BF1F'],
#  'VOLKSWAGEN Jettasel Sedan': ['3VWGZ7A'],
#  'CHEVROLET Sonic Sedan': ['1G1JE5S', '1G1JB5S'],
#  'MERCEDES-BENZ GLK320 Jeep': ['4JGDA5H'],
#  'VOLVO XC60R-Design Jeep': ['YV4902D'],
#  'MERCEDES-BENZ CL500 Coupe': ['WDBPJ75'],
#  'FIAT 500L Universal': ['ZFBCFAC'],
#  'FORD EscapeHybrid Jeep': ['1FMCU59'],
#  'MERCEDES-BENZ C250AMG-PAKET-1,8 Sedan': ['WDDGF4H'],
#  'FORD Escape Universal': ['1FMCU9G'],
#  'FORD Mondeo Sedan': ['7657', '121W'],
#  'MERCEDES-BENZ R350 Universal': ['4JGCB65'],
#  'VOLKSWAGEN CC Sedan': ['WVWZZZ3'],
#  'CHEVROLET Trax1LT Jeep': ['3GNCJLS'],
#  'BMW 1283,0 Coupe': ['WBAUP73'],
#  'HONDA Edix Hatchback': ['1111111'],
#  'FORD F150 Pickup': ['1FTMF1C'],
#  'MERCEDES-BENZ Sprinter308CDI Microbus': ['geocapi'],
#  'FIAT 500Lounge Coupe': ['3C3CFFC'],
#  'HYUNDAI Veloster Sedan': ['KMHTC6A'],
#  'MERCEDES-BENZ 200 Sedan': ['WDB2020'],
#  'MERCEDES-BENZ C3004matic Sedan': ['WDDGF8B'],
#  'BMW X5DIESEL Jeep': ['5UXZW0C'],
#  'KIA OptimaSX Sedan': ['KNAGM4A'],
#  'VOLVO XC90 Jeep': ['YV1CZ59'],
#  'MERCEDES-BENZ E350CGI Sedan': ['WDD2120'],
#  'SUBARU XVcrosstrek Jeep': ['JF2GPAW'],
#  'MAZDA Mazda6 Universal': ['JM1GJ1U'],
#  'FORD FusionTitanium Sedan': ['3FA6P0D'],
#  'MAZDA 616 Sedan': ['JM1GJ1W'],
#  'INFINITI Q50SRed Sedan': ['JN1BV7A'],
#  'NISSAN Skyline Sedan': ['1221'],
#  'VOLKSWAGEN PassatR-line Sedan': ['1VWAT7A'],
#  'BMW X5XDRIVE35D Jeep': ['5UXZWOC'],
#  'KIA CeratoK3 Sedan': ['KNAFJ41'],
#  'MERCURY Mariner Jeep': ['4M2CU29'],
#  'MERCEDES-BENZ E3504matic Sedan': ['WDDHF8H'],
#  'TOYOTA Ist Sedan': ['4545455'],
#  'MITSUBISHI Eclipse Jeep': ['JA4AS3A'],
#  'CHEVROLET CruzePremier Sedan': ['1G1BG5S'],
#  'MERCEDES-BENZ C30AMG Sedan': ['WDDGF54'],
#  'RENAULT Megane Coupe': ['VF1DA0P'],
#  'SSANGYONG Actyon Pickup': ['KPACA1E'],
#  'FERRARI 456 Coupe': ['ZFF67NF'],
#  'MERCEDES-BENZ C240 Sedan': ['1717'],
#  'MERCEDES-BENZ CLA200 Sedan': ['WDDSJ4E'],
#  'BMW X54x4 Jeep': ['5UXZW0C'],
#  'VOLKSWAGEN GolfGTI Hatchback': ['3VW5T7A'],
#  'HYUNDAI SonataHYBRID Sedan': ['KMHEC4A'],
#  'TOYOTA Ist Hatchback': ['TYGR46T'],
#  'DODGE Charger Microbus': ['RR-685M'],
#  'NISSAN QuestLIMITED Minivan': ['JN8AE2K'],
#  'JEEP GrandCherokeelimited Jeep': ['1J4HR58'],
#  'TOYOTA RAV4XLE Jeep': ['2T3WFRE'],
#  'HYUNDAI SonataSPORT Sedan': ['5NPE34A'],
#  'MERCEDES-BENZ ML350BLUETEC Jeep': ['4JGBB2F'],
#  'CHEVROLET Malibueco Sedan': ['1G11D5S'],
#  'FORD FusionSEHYBRID Sedan': ['3FA6P0L'],
#  'VOLKSWAGEN JettaSPORT Sedan': ['3VWD17A'],
#  'MINI CooperCLUBMAN Coupe': ['WMWML3C'],
#  'NISSAN Cube Hatchback': ['JN8AZ2K'],
#  'FORD FocusSEL Sedan': ['1FAHP3H', '1FAHP3M'],
#  'TOYOTA LandCruiserPradoLC150 Jeep': ['JTEBH3F'],
#  'TOYOTA CamryS Sedan': ['4T1B21H'],
#  'FIAT 500Abarth Coupe': ['3C3CFFJ'],
#  'MERCEDES-BENZ C180 Universal': ['WDB2020'],
#  'OPEL VectraC Sedan': ['W0L0ZCF'],
#  'MERCEDES-BENZ ML320DIESEL Jeep': ['4JGBB25'],
#  'MERCEDES-BENZ E350amg Sedan': ['WDDHF8J'],
#  'MERCEDES-BENZ CL550AMG Coupe': ['WDDEJ71'],
#  'TOYOTA Vitz Sedan': ['1111'],
#  'AUDI Q5Premium Jeep': ['WA1KK78'],
#  'MERCEDES-BENZ C300 Cabriolet': ['WDDWK4J'],
#  'HYUNDAI SonataHybrid Sedan': ['KMHEC4A'],
#  'TOYOTA Century Jeep': ['NMTKHMB'],
#  'SUBARU XVpremium Jeep': ['JF2GPAK'],
#  'NISSAN JukeS Jeep': ['JN8AF5M'],
#  'BMW 535i Sedan': ['WBAFR7C'],
#  'VOLKSWAGEN Vento Sedan': ['WVWZZZ1'],
#  'VOLKSWAGEN Golf Sedan': ['WVWDM7A'],
#  'AUDI A6SUPRECHARGE Sedan': ['WAUHGAF'],
#  'BMW X5XDRIVE Jeep': ['5UXFF0C'],
#  'KIA SOUL Sedan': ['KNDJT2A'],
#  'BMW 135 Coupe': ['WBAUC7C'],
#  'FORD FusionPLAGIN Sedan': ['3FA6P0S'],
#  'MERCEDES-BENZ ML400 Jeep': ['4JGDA5G'],
#  'JAGUAR Daimler Sedan': ['SAJWJ2G'],
#  'TOYOTA CorollaIM Hatchback': ['JTNKARJ'],
#  'BMW X3SDRIVE Jeep': ['5UXWZ7C'],
#  'MERCEDES-BENZ E350Amg Sedan': ['WDDHF8H'],
#  'BMW M5Stoki Sedan': ['WBSNB93'],
#  'MITSUBISHI MonteroSport Jeep': ['11111'],
#  'HONDA CivicHybrid Sedan': ['JHMFB4F'],
#  'JEEP LibertyKK Jeep': ['1J4PN2G'],
#  'DODGE RAMPROMASTERCITYPrint Goodswagon': ['ZFBERFA'],
#  'MERCEDES-BENZ E200cdi Sedan': ['WDB2110'],
#  'BENTLEY Bentayga Jeep': ['SJAAC2Z'],
#  'BENTLEY Mulsanne Sedan': ['SCBBG7Z'],
#  'AUDI S8 Sedan': ['WAUK2AF'],
#  'KIA SOULSXL Jeep': ['KNDJX3A'],
#  'NISSAN Tiida Sedan': ['3N1BC1C'],
#  'TOYOTA CamrySEDAN Sedan': ['4T1BF1F'],
#  'OPEL AstraG Hatchback': ['W0L0TGF'],
#  'FORD FocusST Hatchback': ['1FADP3L'],
#  'HYUNDAI SonataECO Sedan': ['5NPE24A'],
#  'SUBARU Foresterlegacy Sedan': ['4S3BNAC'],
#  'FIAT 500SPORT Hatchback': ['3C3CFFB'],
#  'BMW 323 Sedan': ['WBAAM33'],
#  'AUDI A4Sline Sedan': ['WAUKFAF'],
#  'LANDROVER RangeRoverEvoqueრესტა Jeep': ['SALVP2B'],
#  'VAZ 2107 Sedan': ['OOOOO'],
#  'TOYOTA Prius3 Sedan': ['JTDKN3D'],
#  'BMW X635i Jeep': ['5UXFG43'],
#  'MAZDA Mazda3GT Sedan': ['JM1BM1W'],
#  'NISSAN Micra Hatchback': ['NISSANM'],
#  'KIA OptimaECOHYBRID Sedan': ['KNAGN4A'],
#  'LANDROVER Freelander Jeep': ['SALLNAA'],
#  'MERCEDES-BENZ 300 Sedan': ['WDDGF81'],
#  'TOYOTA CamryXV50 Sedan': ['4T1BF1F'],
#  'NISSAN FrontierPRO-4X Pickup': ['1N6AD0E'],
#  'FORD Explorer Jeep': ['1FM5K7D']}
# /home/freeradical/anaconda3/envs/sf/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#    row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 0       0               TOYOTA         Aquas            Sedan
# 1       1        MERCEDES-BENZ          C220            Sedan
# 2       2              HYUNDAI      Veloster        Hatchback
# 3       3              HYUNDAI       SantaFE             Jeep
# 4       4               TOYOTA           CHR             Jeep
#
#    current_mileage  vehicle_year vehicle_gearbox_type doors_cnt  \
# 0           133000          2014            Automatic       4/5
# 1            24500          2010               Manual       4/5
# 2            31000          2016            Tiptronic       2/3
# 3           115459          2015            Automatic       4/5
# 4            18950          2019            Automatic       4/5
#
#                   wheels vehicle_color vehicle_interior_color  \
# 0    Right-hand drive          Silver                  Black
# 1           Left wheel         Silver                  Black
# 2           Left wheel         Silver                  Black
# 3           Left wheel           Blue                  Black
# 4           Left wheel          Black                     NaN
#
#              car_vin  car_leather_interior deal_type  final_price  \
# 0                nan                     0  For Sale       3650.0
# 1            WDB2030                     0  For Sale       6800.0
# 2  KMHTC6AE3GU293912                     1  For Sale       6300.0
# 3            5NMS2CA                     1  For Sale      14488.0
# 4  JTNKHMBX7K1030253                     1  For Sale       5000.0
#
#    car_wearout_ratio
# 0           0.939850
# 1           3.401361
# 2           5.376344
# 3           1.237298
# 4          17.590150

# %%
train_data['car_vin'].value_counts()

# %%
# %%time
import category_encoders as ce

def create_expert_feats(data):
    
    # 1 ++ 
    def modify_car_vin(car_vin):
        if car_vin != np.nan:
            car_vin = str(car_vin)
        else:
            return car_vin
        if len(car_vin) < 11:
            return car_vin
        else:
            return car_vin[:11]
    data['car_vin'] =  data['car_vin'].apply(modify_car_vin)
    
    # 2 +-0
    #создаем словарь имя столбца: число(признак) на который надо заменить пропуски
#     values = {
#         'doors_cnt': data['doors_cnt'].mode()[0],
#         'vehicle_color': data['vehicle_color'].mode()[0],
#         'vehicle_interior_color': data['vehicle_interior_color'].mode()[0]
#     }
#     #заполняем пропуски в соответствии с заявленным словарем
#     data = data.fillna(values)

    # 3 +++
    data['car_wearout_ratio'] = 1e6/((2022 - data['vehicle_year'])*data['current_mileage'])
    
    # 4
#     bin_encoder = ce.BinaryEncoder(cols=['vehicle_category'])
#     type_bin = bin_encoder.fit_transform(data['vehicle_category'])
#     data = pd.concat([data, type_bin], axis=1)
    
#     bin_encoder = ce.BinaryEncoder(cols=['vehicle_gearbox_type'])
#     type_bin = bin_encoder.fit_transform(data['vehicle_gearbox_type'])
#     data = pd.concat([data, type_bin], axis=1)

    display(data.head(3))
    return data
   
train_data = create_expert_feats(train_data)
test_data = create_expert_feats(test_data)
# Out:
#    row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 0       0               TOYOTA        Aqua s            Sedan
# 1       1        MERCEDES-BENZ         C 220            Sedan
# 2       2              HYUNDAI      Veloster        Hatchback
#
#    current_mileage  vehicle_year vehicle_gearbox_type doors_cnt  \
# 0           133000          2014            Automatic       4/5
# 1            24500          2010               Manual       4/5
# 2            31000          2016            Tiptronic       2/3
#
#                   wheels vehicle_color vehicle_interior_color      car_vin  \
# 0    Right-hand drive          Silver                  Black           nan
# 1           Left wheel         Silver                  Black           nan
# 2           Left wheel         Silver                  Black    KMHTC6AE3G
#
#    car_leather_interior deal_type  final_price  car_wearout_ratio
# 0                     0  For Sale       3650.0           0.939850
# 1                     0  For Sale       6800.0           3.401361
# 2                     1  For Sale       6300.0           5.376344
#    row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 0   35000               TOYOTA         Prius        Hatchback
# 1   35001              HYUNDAI       Elantra            Sedan
# 2   35002                LEXUS        NX 300             Jeep
#
#    current_mileage  vehicle_year vehicle_gearbox_type doors_cnt  \
# 0           323733          2012            Automatic       4/5
# 1           112000          2013            Tiptronic       4/5
# 2            16920          2018            Automatic       NaN
#
#            wheels vehicle_color vehicle_interior_color      car_vin  \
# 0    Left wheel           Grey                  Black    JTDKN3DU6C
# 1    Left wheel           Grey                  Black    SURATSHIA
# 2    Left wheel          Brown                     NaN   JTJYARBZ5J
#
#    car_leather_interior deal_type  car_wearout_ratio
# 0                     1  For Sale           0.308897
# 1                     1  For Sale           0.992063
# 2                     1  For Sale          14.775414
# CPU times: user 72.6 ms, sys: 8.06 ms, total: 80.6 ms
# Wall time: 113 ms

# %%
tr_data, te_data = train_test_split(
    train_data, 
    test_size=TEST_SIZE, 
    random_state=RANDOM_STATE
)

print(f'Data splitted. Parts sizes: tr_data = {tr_data.shape}, te_data = {te_data.shape}')

tr_data.head()

# %%
task = Task('reg', loss = 'mae', metric = 'mae')

# %%
roles = {
    'target': TARGET_NAME,
    'drop': ['row_ID']
}
