# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# # Загрузка данных

# %%
data = pd.read_excel('../data/data_ford_price.xlsx')

# %% [markdown]
# ## Предобработка данных

# %%
data = data[['price','year', 'cylinders', 'odometer', 'lat', 'long', 'weather']]
data.dropna(inplace = True)

y = data['price']
x = data.drop(columns='price')

# %% [markdown]
# ## Обучение модели

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=40)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_predicted = model.predict(X_test)
 
mae = mean_absolute_error(y_test, y_predicted)
print('MAE: %.3f' % mae)
# Out:
# MAE: 4682.957

# %% [markdown]
# #  Отбор признаков: классификация методов

# %% [markdown]
# ## Метод рекурсивного исключения признаков

# %%
from sklearn.feature_selection import RFE

# %%
estimator = LinearRegression()
selector = RFE(estimator, n_features_to_select=3, step=1)
selector = selector.fit(X_train, y_train)

# %%
cols_to_del = list(selector.get_feature_names_out())

cols_to_del.append('price')
print(cols_to_del)
x = data.drop(columns=cols_to_del)
# Out:
# ['year', 'cylinders', 'lat', 'price']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=40)
X_train.columns
# Out:
# Index(['odometer', 'long', 'weather'], dtype='object')

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_predicted = model.predict(X_test)
 
mae = mean_absolute_error(y_test, y_predicted)
print('MAE: %.3f' % mae)
# Out:
# MAE: 7275.133

# %% [markdown]
# ##  МЕТОДЫ ВЫБОРА ПРИЗНАКОВ НА ОСНОВЕ ФИЛЬТРОВ

# %%
from sklearn.feature_selection import SelectKBest, f_regression

# %%
y = data['price']
x = data.drop(columns='price')
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=40)

# %%
selector = SelectKBest(f_regression, k=3)
selector.fit(X_train, y_train)
selector.get_feature_names_out()
# Out:
# array(['year', 'cylinders', 'odometer'], dtype=object)

# %%
cols_to_del = list(selector.get_feature_names_out())
cols_to_del.append('price')
print(cols_to_del)
x = data.drop(columns=cols_to_del)
# Out:
# ['year', 'cylinders', 'odometer', 'price']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=40)
X_train.columns
# Out:
# Index(['lat', 'long', 'weather'], dtype='object')

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_predicted = model.predict(X_test)
 
mae = mean_absolute_error(y_test, y_predicted)
print('MAE: %.3f' % mae)
# Out:
# MAE: 8812.414

# %% [markdown]
# ### Выводы:
# #### метод рекурсивного исключения показал большую эффективность на нашем датасете в сравнении с методом на основе фильтров.
